# %%
# import library for EDA
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\Dipesh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#import the dataset
df=pd.read_csv('cause_of_deaths dataset.csv')
df.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
#Checking shape of dataset
df.shape
# Out:
# (6120, 34)

# %%
# checking null values 
df.isnull().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
#  check  the duplicate
duplicate = df[df.duplicated()]
print("Duplicate Rows :")
 
#  Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Country/Territory, Code, Year, Meningitis, Alzheimer's Disease and Other Dementias, Parkinson's Disease, Nutritional Deficiencies, Malaria, Drowning, Interpersonal Violence, Maternal Disorders, HIV/AIDS, Drug Use Disorders, Tuberculosis, Cardiovascular Diseases, Lower Respiratory Infections, Neonatal Disorders, Alcohol Use Disorders, Self-harm, Exposure to Forces of Nature, Diarrheal Diseases, Environmental Heat and Cold Exposure, Neoplasms, Conflict and Terrorism, Diabetes Mellitus, Chronic Kidney Disease, Poisonings, Protein-Energy Malnutrition, Road Injuries, Chronic Respiratory Diseases, Cirrhosis and Other Chronic Liver Diseases, Digestive Diseases, Fire, Heat, and Hot Substances, Acute Hepatitis]
# Index: []
#
# [0 rows x 34 columns]

# %%
#describing the dataset
df.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
cause_of_deaths = ['Meningitis','Alzheimer\'s Disease and Other Dementias', 'Parkinson\'s Disease','Nutritional Deficiencies', 'Malaria', 'Drowning','Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS','Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
'Lower Respiratory Infections', 'Neonatal Disorders','Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature','Diarrheal Diseases', 'Environmental Heat and Cold Exposure','Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition','Road Injuries', 'Chronic Respiratory Diseases','Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases','Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
# adding one extra column and that is total number of death
df['Total_no_of_Deaths'] = df[cause_of_deaths].sum(axis=1)

# %%
df.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
y = df['Country/Territory']
x = df["Total_no_of_Deaths"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)

# %% [markdown]
# # From the Above graph, we observe the highest total number of death of all people from all countries like the United States, Russia, India, China, Indonesia, Brazil, and Nigeria.

# %%
Countries_Total_no_of_Deaths_noyear_df = df.groupby('Country/Territory').sum()
Countries_Total_no_of_Deaths_noyear_df.drop('Year',axis=1,inplace=True)

# %%
Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[:5]
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# China                  480899                                  5381846
# India                 2008944                                  1707561
# United States           40032                                  3302609
# Russia                  60519                                   972305
# Indonesia              337724                                   487566
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# China                          1533092                    584236    13418
# India                           756832                   3290569  2439244
# United States                   661288                    133044        0
# Russia                          236367                     15906        0
# Indonesia                       145752                    604467    74664
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['India','Russia','Indonesia','United States','China']
sizes = [238158165,59591155, 44046941, 71197802, 265408106]

#fig, ax = plt.subplots(figsize =(10, 5))
fig, ax = plt.subplots(figsize=(10,10))
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Top 5 Highest Number of People Death Due to Disease')


plt.show()

# %% [markdown]
# # The above pie chart shows the Top 5 Countries in which the Total Number of death is the highest among all countries.

# %% [markdown]
# ##  Now we select this top 5 country for further analysis

# %% [markdown]
# ### now we are going to analysis top 10 reason why people die so much in that top 5 country

# %%
# analysis On China
china_top_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[:1]

# %%
china_top_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       100505973
# Neoplasms                                      61060527
# Chronic Respiratory Diseases                   36676826
# Digestive Diseases                              8924906
# Lower Respiratory Infections                    8525819
# Road Injuries                                   8350399
# Alzheimer's Disease and Other Dementias         5381846
# Self-harm                                       5078550
# Cirrhosis and Other Chronic Liver Diseases      4918899
# Neonatal Disorders                              4353666
# Name: China, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
china_top_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='bar')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in China")
plt.show()

# %% [markdown]
# ## The above bar chart shows the top 10 diseases why people death is more in china, first and the main reason is due to Cardiovascular Disease followed by Neoplasms and Chronic Respiratory Disease.

# %%
# analysis On India
India_top_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[1:2]

# %%
India_top_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       52994710
# Diarrheal Diseases                            26243547
# Chronic Respiratory Diseases                  25232974
# Neonatal Disorders                            20911570
# Neoplasms                                     17762703
# Lower Respiratory Infections                  16419404
# Tuberculosis                                  15820922
# Digestive Diseases                            11804380
# Cirrhosis and Other Chronic Liver Diseases     6294910
# Self-harm                                      5543395
# Name: India, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
India_top_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='bar')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in India")
plt.show()

# %% [markdown]
# ## The above bar chart shows the top 10 diseases why people death is more in India, first and the main reason is due to Cardiovascular Disease followed by Diarrheal Disease, Chronic Respiratory Disease, and Neonatal Disorders.

# %%
# analysis on United State
usa_top_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[2:3]

# %%
usa_top_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       26438346
# Neoplasms                                     18905315
# Chronic Respiratory Diseases                   4949052
# Alzheimer's Disease and Other Dementias        3302609
# Digestive Diseases                             3026943
# Lower Respiratory Infections                   2248625
# Diabetes Mellitus                              2030631
# Chronic Kidney Disease                         2018497
# Cirrhosis and Other Chronic Liver Diseases     1514325
# Road Injuries                                  1359744
# Name: United States, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
usa_top_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='bar')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in United States")
plt.show()

# %% [markdown]
# ## The above bar chart shows the top 10 diseases why people death is more in United States, first and the main reason is due to Cardiovascular Disease followed by Neoplasms.

# %%
# Analysis on Russia
russia_top_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[3:4]

# %%
russia_top_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       33903781
# Neoplasms                                      9079313
# Digestive Diseases                             2398456
# Self-harm                                      1793855
# Chronic Respiratory Diseases                   1518195
# Cirrhosis and Other Chronic Liver Diseases     1233608
# Interpersonal Violence                         1215179
# Alcohol Use Disorders                          1194672
# Lower Respiratory Infections                   1113475
# Road Injuries                                  1067225
# Name: Russia, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
russia_top_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='bar')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in Russia")
plt.show()

# %% [markdown]
# ## The above bar chart shows the top 10 diseases why people death is more in Russia, first and the main reason is due to Cardiovascular Disease followed by Neoplasms.

# %%
# Analysis on Indonesia
indonesia_top_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[4:5]

# %%
indonesia_top_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       13587011
# Neoplasms                                      4672674
# Digestive Diseases                             3204787
# Tuberculosis                                   3197011
# Diarrheal Diseases                             2590656
# Chronic Respiratory Diseases                   2559457
# Cirrhosis and Other Chronic Liver Diseases     2249388
# Neonatal Disorders                             2238128
# Diabetes Mellitus                              1888549
# Lower Respiratory Infections                   1820769
# Name: Indonesia, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
indonesia_top_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='bar')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in Indonesia")
plt.show()

# %% [markdown]
# ## The above bar chart shows the top 10 diseases why people death is more in Indonesia, first and the main reason is due to Cardiovascular Disease followed by Neoplasms and Digestive Diseases.

# %% [markdown]
# ### Making new dataset of this top 5 Countries for futher analysis [India , Russia , Indonesia , China , United States]

# %%
gk = df.groupby('Country/Territory')

# %%
gk.first()
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Afghanistan        AFG  1990        2159
# Albania            ALB  1990         107
# Algeria            DZA  1990         838
# American Samoa     ASM  1990           1
# Andorra            AND  1990           0
# ...                ...   ...         ...
# Venezuela          VEN  1990         666
# Vietnam            VNM  2007        1214
# Yemen              YEM  2007         706
# Zambia             ZMB  1990        4562
# Zimbabwe           ZWE  1990        1132
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                           1116
# Albania                                                360
# Algeria                                               1337
# American Samoa                                           3
# Andorra                                                  6
# ...                                                    ...
# ...

# %%
gk.get_group('China')
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 1110             China  CHN  2007        8407
# 1111             China  CHN  2008        8384
# 1112             China  CHN  2009        8394
# 1113             China  CHN  2010        8341
# 1114             China  CHN  2011        8193
# 1115             China  CHN  2012        8057
# 1116             China  CHN  2013        7971
# 1117             China  CHN  2014        7740
# 1118             China  CHN  2015        7553
# 1119             China  CHN  2016        7550
# 1120             China  CHN  1990       37473
# 1121             China  CHN  1991       36834
# 1122             China  CHN  1992       35086
# 1123             China  CHN  1993       33396
# 1124             China  CHN  1994       31752
# 1125             China  CHN  1995       29319
# 1126             China  CHN  1996       26788
# 1127             China  CHN  1997       23987
# 1128             China  CHN  1998       21485
# ...

# %%
df2=gk.get_group('China')

# %%
gk.get_group('India')
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 2430             India  IND  2007       62224
# 2431             India  IND  2008       60843
# 2432             India  IND  2009       58449
# 2433             India  IND  2012       53433
# 2434             India  IND  2013       52065
# 2435             India  IND  2015       45025
# 2436             India  IND  1990       98358
# 2437             India  IND  1991       97134
# 2438             India  IND  1992       94891
# 2439             India  IND  1993       91783
# 2440             India  IND  1994       88221
# 2441             India  IND  1995       86142
# 2442             India  IND  1996       83642
# 2443             India  IND  1997       82891
# 2444             India  IND  1998       80366
# 2445             India  IND  1999       78524
# 2446             India  IND  2000       77606
# 2447             India  IND  2001       75064
# 2448             India  IND  2002       71130
# ...

# %%
df3=gk.get_group('India')

# %%
gk.get_group('Indonesia')
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 2460         Indonesia  IDN  2007       10001
# 2461         Indonesia  IDN  2008        9608
# 2462         Indonesia  IDN  2009        9183
# 2463         Indonesia  IDN  2013        7915
# 2464         Indonesia  IDN  2015        6946
# 2465         Indonesia  IDN  2016        6469
# 2466         Indonesia  IDN  1990       19261
# 2467         Indonesia  IDN  1991       18316
# 2468         Indonesia  IDN  1992       17432
# 2469         Indonesia  IDN  1993       16722
# 2470         Indonesia  IDN  1994       16025
# 2471         Indonesia  IDN  1995       15296
# 2472         Indonesia  IDN  1996       14587
# 2473         Indonesia  IDN  1997       14036
# 2474         Indonesia  IDN  1998       13744
# 2475         Indonesia  IDN  1999       13254
# 2476         Indonesia  IDN  2000       12754
# 2477         Indonesia  IDN  2001       12514
# 2478         Indonesia  IDN  2002       12168
# ...

# %%
df4=gk.get_group('Indonesia')

# %%
gk.get_group('Russia')
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 4470            Russia  RUS  1990        2255
# 4471            Russia  RUS  1991        2199
# 4472            Russia  RUS  1992        2253
# 4473            Russia  RUS  1993        2564
# 4474            Russia  RUS  1994        2803
# 4475            Russia  RUS  1995        2689
# 4476            Russia  RUS  1996        2387
# 4477            Russia  RUS  1997        2203
# 4478            Russia  RUS  1998        2112
# 4479            Russia  RUS  1999        2230
# 4480            Russia  RUS  2000        2315
# 4481            Russia  RUS  2001        2362
# 4482            Russia  RUS  2002        2380
# 4483            Russia  RUS  2003        2402
# 4484            Russia  RUS  2004        2310
# 4485            Russia  RUS  2005        2337
# 4486            Russia  RUS  2006        2121
# 4487            Russia  RUS  2007        1982
# 4488            Russia  RUS  2008        1929
# ...

# %%
df5=gk.get_group('Russia')

# %%
gk.get_group('United States')
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 5820     United States  USA  2007        1249
# 5821     United States  USA  2008        1223
# 5822     United States  USA  2009        1186
# 5823     United States  USA  2010        1141
# 5824     United States  USA  2011        1126
# 5825     United States  USA  2012        1108
# 5826     United States  USA  2013        1106
# 5827     United States  USA  2014        1102
# 5828     United States  USA  2015        1115
# 5829     United States  USA  2016        1131
# 5830     United States  USA  1990        1830
# 5831     United States  USA  1991        1615
# 5832     United States  USA  1992        1558
# 5833     United States  USA  1993        1550
# 5834     United States  USA  1994        1530
# 5835     United States  USA  1995        1514
# 5836     United States  USA  1996        1504
# 5837     United States  USA  1997        1514
# 5838     United States  USA  1998        1517
# ...

# %%
df6=gk.get_group('United States')

# %%
frames = [df2, df3, df4, df5, df6]
  
result = pd.concat(frames)
display(result)
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 1110             China  CHN  2007        8407
# 1111             China  CHN  2008        8384
# 1112             China  CHN  2009        8394
# 1113             China  CHN  2010        8341
# 1114             China  CHN  2011        8193
# ...                ...  ...   ...         ...
# 5845     United States  USA  2005        1288
# 5846     United States  USA  2006        1273
# 5847     United States  USA  2017        1137
# 5848     United States  USA  2018        1142
# 5849     United States  USA  2019        1146
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 1110                                   187358                52766
# 1111                                   197380                54828
# 1112                                   208139                57485
# 1113                                   218436                60241
# 1114                                   225852                61781
# ...

# %% [markdown]
# ## Now Comparing All Disease With this top 5 country to observe which Country is most affected by which Disease.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Year' , y="Meningitis" , data=result ,hue='Country/Territory')
plt.legend( loc ="upper left")
plt.show()

# %% [markdown]
# ## From the above Line graph, we observe people dying


# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Year' , y='Acute Hepatitis' , data=result ,hue='Country/Territory')
plt.legend( loc ="upper left")
plt.show()

# %% [markdown]
# ## From the above Line graph, we observe people dying due to Acute Hepatitis was High in India and gradually decreasing, the count in china for starting the year 1990 was near about 25000 and the count decreased till the year 2019 which was less than 100000, and for other 3 countries the count remains constant, but for India, if we observe the count for the year 2019 the people die due to Acute Hepatitis is very much high as compare to other 4 countries.

# %% [markdown]
# # Which Top 5 Disease Kill high number of people

# %%
df1=df.sum(axis=0) 
df1
# Out:
# Country/Territory                             AfghanistanAfghanistanAfghanistanAfghanistanAf...
# Code                                          AFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGA...
# Year                                                                                   12267540
# Meningitis                                                                             10524572
# Alzheimer's Disease and Other Dementias                                                29768839
# Parkinson's Disease                                                                     7179795
# Nutritional Deficiencies                                                               13792032
# Malaria                                                                                25342676
# Drowning                                                                               10301999
# Interpersonal Violence                                                                 12752839
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Cardiovascular Diseases','Neoplasms','Lower Respiratory Infections','Neonatal Disorders','Chronic Respiratory Diseases']
sizes = [447741982,229758538, 83770038, 76860729, 104605334]

#fig, ax = plt.subplots(figsize =(10, 5))
fig, ax = plt.subplots(figsize=(10,10))
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Top 5 Disease That kill Highest Number of People')


plt.show()

# %% [markdown]
# ## The above Pie chart shows Top 5 Disease that kill high number of people

# %%
df.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis',
#        'Total_no_of_Deaths'],
#       dtype='object')

# %%
df7=df[['Country/Territory', 'Code', 'Year','Cardiovascular Diseases','Neoplasms','Chronic Respiratory Diseases', 'Lower Respiratory Infections', 'Neonatal Disorders']]
df7
# Out:
#      Country/Territory Code  Year  Cardiovascular Diseases  Neoplasms  \
# 0          Afghanistan  AFG  1990                    44899      11580
# 1          Afghanistan  AFG  1991                    45492      11796
# 2          Afghanistan  AFG  1992                    46557      12218
# 3          Afghanistan  AFG  1993                    47951      12634
# 4          Afghanistan  AFG  1994                    49308      12914
# ...                ...  ...   ...                      ...        ...
# 6115          Zimbabwe  ZWE  2015                    16649      11161
# 6116          Zimbabwe  ZWE  2016                    16937      11465
# 6117          Zimbabwe  ZWE  2017                    17187      11744
# 6118          Zimbabwe  ZWE  2018                    17460      12038
# 6119          Zimbabwe  ZWE  2019                    17810      12353
#
#       Chronic Respiratory Diseases  Lower Respiratory Infections  \
# ...

# %%
gk = df7.groupby('Year')

# %%
gk.first()
# Out:
#      Country/Territory Code  Cardiovascular Diseases  Neoplasms  \
# Year
# 1990       Afghanistan  AFG                    44899      11580
# 1991       Afghanistan  AFG                    45492      11796
# 1992       Afghanistan  AFG                    46557      12218
# 1993       Afghanistan  AFG                    47951      12634
# 1994       Afghanistan  AFG                    49308      12914
# 1995       Afghanistan  AFG                    50158      13106
# 1996       Afghanistan  AFG                    51125      13335
# 1997       Afghanistan  AFG                    52039      13572
# 1998       Afghanistan  AFG                    52720      13695
# 1999       Afghanistan  AFG                    53413      13811
# 2000       Afghanistan  AFG                    53919      13977
# 2001       Afghanistan  AFG                    54642      14312
# 2002       Afghanistan  AFG                    54213      14437
# 2003       Afghanistan  AFG                    54274      14951
# ...

# %%
df8=gk.get_group(1990)
df8
# Out:
#      Country/Territory Code  Year  Cardiovascular Diseases  Neoplasms  \
# 0          Afghanistan  AFG  1990                    44899      11580
# 30             Albania  ALB  1990                     6701       2616
# 60             Algeria  DZA  1990                    53488      10571
# 90      American Samoa  ASM  1990                       66         31
# 120            Andorra  AND  1990                       65        101
# ...                ...  ...   ...                      ...        ...
# 5970         Venezuela  VEN  1990                    25991      12533
# 6007           Vietnam  VNM  1990                   124200      44832
# 6039             Yemen  YEM  1990                    25373       4545
# 6060            Zambia  ZMB  1990                     7826       4635
# 6090          Zimbabwe  ZWE  1990                     9099       5977
#
#       Chronic Respiratory Diseases  Lower Respiratory Infections  \
# ...

# %% [markdown]
# ## Now Comparing This Top 5 Disease with All Country where it affect the most (In Which Country)

# %%
y = df['Country/Territory']
x = df["Cardiovascular Diseases"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)
plt.savefig('Cardiovascular.png')

# %% [markdown]
# ## From the above Scatter plot (Country/Territory VS Cardiovascular Diseases) we observe the most number of people who died due to Cardiovascular Diseases in the countries like United States , Russia, India , China.

# %%
y = df['Country/Territory']
x = df["Neoplasms"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)
plt.savefig('Neoplasms.png')

# %% [markdown]
# ## From the above Scatter plot (Country/Territory VS Neoplasms) we observe the most number of people who died due to Neoplasms in the countries like United States ,India , China.

# %%
y = df['Country/Territory']
x = df["Chronic Respiratory Diseases"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)
plt.savefig('Chronic Respiratory Diseases.png')

# %% [markdown]
# ## From the above Scatter plot (Country/Territory VS Chronic Respiratory Disease) we observe the most number of people who died due to Chronic Kidney Disease in the countries like United States , Pakistan , Mexico,Indonesia,India,China,Brazil,Japan.

# %%
y = df['Country/Territory']
x = df["Lower Respiratory Infections"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)
plt.savefig('Lower Respiratory Infections.png')

# %% [markdown]
# ## From the above Scatter plot (Country/Territory VS Lower Respiratory Infections) we observe the most number of people who died due to Lower Respiratory Infections in the countries like Nigeria, India , China.

# %%
y = df['Country/Territory']
x = df["Neonatal Disorders"]

plt.figure(figsize=(20, 40))
plt.scatter(x, y)
plt.savefig('Neonatal Disorders.png')

# %% [markdown]
# ## From the above Scatter plot (Country/Territory VS Neonatal Disorders) we observe the most number of people who died due to Neonatal Disorders in the countries like Nigeria, Pakistan,India , China , Bangladesh.

# %% [markdown]
# # Conclusion
#
# 1] From the further analysis, we observe the top 5 country that has high mortality and morbidity that is China, India, Russia, Unites States, and Indonesia.
#
# 32 From the further analysis, we observe the top 5 diseases that kill most of the people in the country are Cardiovascular Diseases, Neoplasms, Chronic Respiratory Diseases, Lower Respiratory Infections, Neonatal Disorders, etc.
#
# 3] We also further analyzed the top 5 countries why the death of people is most from which disease each country.
