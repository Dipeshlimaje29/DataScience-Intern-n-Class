# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %% [markdown]
# ## Delhi location

# %%
# click search button
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2020 Maruti Swift',
#  '2020 KIA SELTOS',
#  '2020 Maruti Swift',
#  '2020 KIA SELTOS',
#  '2019 Hyundai Grand i10',
#  '2019 Hyundai Grand i10',
#  '2019 Hyundai Grand i10',
#  '2009 Maruti Swift Dzire',
#  '2021 Maruti Swift',
#  '2020 KIA SONET',
#  '2022 Maruti New Wagon-R',
#  '2020 KIA SELTOS',
#  '2021 Maruti Swift',
#  '2021 Maruti Celerio',
#  '2020 KIA SELTOS',
#  '2010 Honda City',
#  '2020 Maruti Swift',
#  '2019 KIA SELTOS',
#  '2019 KIA SELTOS',
#  '2015 Toyota Corolla Altis',
#  '2011 Maruti Wagon R 1.0',
#  '2020 KIA SELTOS',
#  '2022 Skoda KUSHAQ',
#  '2012 Honda City',
#  '2015 Toyota Camry',
#  '2019 KIA SELTOS',
#  '2021 KIA SONET',
#  '2019 KIA SELTOS',
#  '2010 Maruti Alto',
#  '2020 KIA SONET',
#  '2021 Hyundai VENUE',
#  '2020 KIA SELTOS',
#  '2021 Renault Kiger',
#  '2012 Hyundai i10',
#  '2015 Hyundai Eon',
#  '2021 Maruti New Wagon-R',
#  '2019 KIA SELTOS',
#  '2012 Maruti Swift Dzire',
#  '2013 Maruti Alto 800',
#  '2021 Hyundai VENUE',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])

# %%
manu_year
# Out:
# ['2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2009',
#  '2021',
#  '2020',
#  '2022',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2010',
#  '2020',
#  '2019',
#  '2019',
#  '2015',
#  '2011',
#  '2020',
#  '2022',
#  '2012',
#  '2015',
#  '2019',
#  '2021',
#  '2019',
#  '2010',
#  '2020',
#  '2021',
#  '2020',
#  '2021',
#  '2012',
#  '2015',
#  '2021',
#  '2019',
#  '2012',
#  '2013',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2020',
#  '2021',
#  '2014',
#  '2012',
#  '2019',
#  '2013',
#  '2013',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2012',
#  '2014',
#  '2013',
#  '2019',
#  '2014',
#  '2014',
#  '2012',
#  '2014',
#  '2020',
#  '2018',
#  '2014',
#  '2014',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2014',
#  '2022',
#  '2021',
#  '2011',
#  '2022',
#  '2020',
#  '2021',
#  '2022',
#  '2018',
#  '2010',
#  '2021',
#  '2021',
#  '2021',
#  '2011',
#  '2014',
#  '2022',
#  '2010',
#  '2019',
#  '2013',
#  '2011',
# ...

# %%
len(manu_year)
# Out:
# 500

# %%
#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])

# %%
len(Brand)
# Out:
# 500

# %%
Brand
# Out:
# ['Maruti',
#  'KIA',
#  'Maruti',
#  'KIA',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'Honda',
#  'Maruti',
#  'KIA',
#  'KIA',
#  'Toyota',
#  'Maruti',
#  'KIA',
#  'Skoda',
#  'Honda',
#  'Toyota',
#  'KIA',
#  'KIA',
#  'KIA',
#  'Maruti',
#  'KIA',
#  'Hyundai',
#  'KIA',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'KIA',
#  'Renault',
#  'Hyundai',
#  'Toyota',
#  'Renault',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Tata',
#  'KIA',
#  'Renault',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'KIA',
#  'Hyundai',
#  'Volkswagen',
#  'Maruti',
#  'Honda',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Honda',
#  'Renault',
#  'Renault',
#  'Renault',
#  'Hyundai',
#  'Ford',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Renault',
#  'Datsun',
#  'Maruti',
#  'Renault',
#  'Datsun',
# ...

# %%
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])

# %%
Model
# Out:
# [['Swift'],
#  ['SELTOS'],
#  ['Swift'],
#  ['SELTOS'],
#  ['Grand', 'i10'],
#  ['Grand', 'i10'],
#  ['Grand', 'i10'],
#  ['Swift', 'Dzire'],
#  ['Swift'],
#  ['SONET'],
#  ['New', 'Wagon-R'],
#  ['SELTOS'],
#  ['Swift'],
#  ['Celerio'],
#  ['SELTOS'],
#  ['City'],
#  ['Swift'],
#  ['SELTOS'],
#  ['SELTOS'],
#  ['Corolla', 'Altis'],
#  ['Wagon', 'R', '1.0'],
#  ['SELTOS'],
#  ['KUSHAQ'],
#  ['City'],
#  ['Camry'],
#  ['SELTOS'],
#  ['SONET'],
#  ['SELTOS'],
#  ['Alto'],
#  ['SONET'],
#  ['VENUE'],
#  ['SELTOS'],
#  ['Kiger'],
#  ['i10'],
#  ['Eon'],
#  ['New', 'Wagon-R'],
#  ['SELTOS'],
#  ['Swift', 'Dzire'],
#  ['Alto', '800'],
#  ['VENUE'],
#  ['SELTOS'],
#  ['Kiger'],
#  ['NEW', 'I20'],
#  ['URBAN', 'CRUISER'],
#  ['Kiger'],
#  ['Grand', 'i10'],
#  ['Swift', 'Dzire'],
#  ['Swift'],
#  ['i20'],
#  ['Wagon', 'R', 'Stingray'],
#  ['Safari'],
#  ['SELTOS'],
#  ['Kwid'],
#  ['Swift'],
#  ['A', 'Star'],
#  ['i20'],
#  ['Wagon', 'R', 'Stingray'],
#  ['SELTOS'],
#  ['Grand', 'i10'],
# ...

# %%
len(Model)
# Out:
# 500

# %%
#//p[@class="cvakB"]/span

# %%
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)

# %%
len(trans)
# Out:
# 500

# %%
trans
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Automatic',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  '',
#  'Manual',
#  '',
#  '',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  '',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
# ...

# %%
#//ul[@class="bVR0c"]

# %%
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])

# %%
owner
# Out:
# ['1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
len(owner)
# Out:
# 500

# %%
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])

# %%
km_driven
# Out:
# ['22,826 km',
#  '5,999 km',
#  '16,691 km',
#  '9,417 km',
#  '19,964 km',
#  '29,505 km',
#  '20,969 km',
#  '26,645 km',
#  '12,742 km',
#  '12,461 km',
#  '3,028 km',
#  '10,678 km',
#  '7,906 km',
#  '10,518 km',
#  '18,469 km',
#  '47,886 km',
#  '3,192 km',
#  '25,750 km',
#  '19,207 km',
#  '1,00,530 km',
#  '33,043 km',
#  '28,506 km',
#  '2,696 km',
#  '62,560 km',
#  '93,626 km',
#  '39,585 km',
#  '6,978 km',
#  '24,991 km',
#  '55,637 km',
#  '12,835 km',
#  '6,059 km',
#  '49,350 km',
#  '6,593 km',
#  '50,220 km',
#  '26,897 km',
#  '3,897 km',
#  '53,070 km',
#  '45,557 km',
#  '24,093 km',
#  '12,717 km',
#  '60,147 km',
#  '2,404 km',
#  '16,818 km',
#  '22,874 km',
#  '23,318 km',
#  '36,938 km',
#  '61,580 km',
#  '1,994 km',
#  '56,073 km',
#  '21,135 km',
#  '8,582 km',
#  '26,495 km',
#  '10,089 km',
#  '24,856 km',
#  '84,057 km',
#  '58,879 km',
#  '28,836 km',
#  '13,672 km',
#  '57,770 km',
#  '66,786 km',
#  '31,953 km',
#  '11,353 km',
#  '12,981 km',
# ...

# %%
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])

# %%
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
# ...

# %%
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
price
# Out:
# ['₹5,22,000',
#  '₹17,22,000',
#  '₹5,30,000',
#  '₹16,81,000',
#  '₹5,03,000',
#  '₹5,69,000',
#  '₹5,30,000',
#  '₹2,08,000',
#  '₹5,91,000',
#  '₹13,39,000',
#  '₹5,26,000',
#  '₹13,58,000',
#  '₹6,52,000',
#  '₹4,88,000',
#  '₹16,91,000',
#  '₹3,16,000',
#  '₹6,34,700',
#  '₹11,01,000',
#  '₹12,88,000',
#  '₹8,30,000',
#  '₹2,79,000',
#  '₹16,78,000',
#  '₹18,48,000',
#  '₹3,80,000',
#  '₹12,43,000',
#  '₹11,54,000',
#  '₹12,62,000',
#  '₹11,11,000',
#  '₹1,72,000',
#  '₹13,40,000',
#  '₹8,74,000',
#  '₹14,45,000',
#  '₹8,06,000',
#  '₹2,66,000',
#  '₹2,77,000',
#  '₹5,27,000',
#  '₹10,66,000',
#  '₹3,31,000',
#  '₹2,38,000',
#  '₹8,34,000',
#  '₹14,66,000',
#  '₹10,40,000',
#  '₹7,10,000',
#  '₹11,05,000',
#  '₹6,76,000',
#  '₹3,90,000',
#  '₹3,64,000',
#  '₹5,68,000',
#  '₹3,85,000',
#  '₹3,18,000',
#  '₹21,92,000',
#  '₹13,22,000',
#  '₹4,82,000',
#  '₹6,52,000',
#  '₹2,79,000',
#  '₹4,57,000',
#  '₹3,11,000',
#  '₹14,73,000',
#  '₹4,09,000',
#  '₹3,44,000',
#  '₹2,65,000',
# ...

# %%
len(price)
# Out:
# 500

# %%
#creating dataframe 

DF1=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Delhi','Price':price})
DF1
# Out:
#        Brand            Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0     Maruti          [Swift]      2020        22,826 km  Petrol       Manual
# 1        KIA         [SELTOS]      2020         5,999 km  Petrol       Manual
# 2     Maruti          [Swift]      2020        16,691 km  Petrol       Manual
# 3        KIA         [SELTOS]      2020         9,417 km  Petrol    Automatic
# 4    Hyundai     [Grand, i10]      2019        19,964 km  Petrol       Manual
# ..       ...              ...       ...              ...     ...          ...
# 495  Hyundai     [Grand, i10]      2018        20,335 km  Petrol       Manual
# 496   Maruti           [Ciaz]      2019        39,599 km  Petrol       Manual
# 497   Maruti          [Swift]      2018        31,090 km  Petrol    Automatic
# 498   Maruti   [New, Wagon-R]      2020        26,230 km  Petrol       Manual
# 499   Maruti  [Wagon, R, 1.0]      2018        41,315 km  Petrol       Manual
#
# ...

# %%
DF1.to_csv('car_data_1.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %% [markdown]
# # Mumbai location

# %%
# click search button
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')
search_btn.click()

# %%
#/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[2]/a

# %%
# click search button
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[2]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
car_name
# Out:
# ['2012 Honda City',
#  '2016 Maruti Swift Dzire',
#  '2015 Maruti Ciaz',
#  '2016 Ford Ecosport',
#  '2013 Maruti Alto 800',
#  '2012 Honda City',
#  '2018 Ford Endeavour',
#  '2013 Maruti Alto 800',
#  '2021 Mahindra Thar',
#  '2019 Hyundai NEW SANTRO',
#  '2016 Renault Kwid',
#  '2018 Mahindra XUV500',
#  '2017 Maruti Baleno',
#  '2020 Renault Kwid',
#  '2022 KIA CARENS',
#  '2017 Hyundai New Elantra',
#  '2014 Hyundai Grand i10',
#  '2019 Hyundai NEW SANTRO',
#  '2018 Volkswagen Polo',
#  '2011 Mercedes Benz E Class',
#  '2012 Honda City',
#  '2016 Maruti Swift Dzire',
#  '2015 Maruti Ciaz',
#  '2016 Ford Ecosport',
#  '2013 Maruti Alto 800',
#  '2012 Honda City',
#  '2018 Ford Endeavour',
#  '2013 Maruti Alto 800',
#  '2021 Mahindra Thar',
#  '2019 Hyundai NEW SANTRO',
#  '2016 Renault Kwid',
#  '2018 Mahindra XUV500',
#  '2017 Maruti Baleno',
#  '2020 Renault Kwid',
#  '2022 KIA CARENS',
#  '2017 Hyundai New Elantra',
#  '2014 Hyundai Grand i10',
#  '2019 Hyundai NEW SANTRO',
# ...

# %%
len(car_name)
# Out:
# 500

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])

# %%
#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])

# %%
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])

# %%
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)

# %%
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])

# %%
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])

# %%
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])

# %%
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF2=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Mumbai','Price':price})
DF2
# Out:
#        Brand            Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0      Honda           [City]      2012        90,080 km  Petrol    Automatic
# 1     Maruti   [Swift, Dzire]      2016        16,495 km  Petrol       Manual
# 2     Maruti           [Ciaz]      2015        57,943 km  Petrol
# 3       Ford       [Ecosport]      2016        46,122 km  Petrol       Manual
# 4     Maruti      [Alto, 800]      2013         4,738 km  Petrol       Manual
# ..       ...              ...       ...              ...     ...          ...
# 495  Hyundai     [Elite, i20]      2015        27,655 km  Petrol       Manual
# 496   Maruti        [Celerio]      2016        94,914 km     CNG       Manual
# 497    Honda           [City]      2017        43,877 km  Petrol    Automatic
# 498   Maruti      [Alto, 800]      2016        16,279 km  Petrol       Manual
# 499   Maruti  [Wagon, R, 1.0]      2015        77,999 km     CNG       Manual
#
#     Number_of_owners Location      Price
# ...

# %%
DF2.to_csv('car_data_2.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
# click search button (location manually)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')
search_btn.click()

# %% [markdown]
# # Banguluru location

# %%
# click search button
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[3]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2016 Maruti Ertiga',
#  '2018 Tata Tiago',
#  '2018 Volkswagen Vento',
#  '2018 Tata Tiago',
#  '2019 Renault Kwid',
#  '2012 Volkswagen Polo',
#  '2013 Hyundai Verna',
#  '2016 Renault Kwid',
#  '2021 Renault Kwid',
#  '2020 Maruti XL6',
#  '2014 Maruti Swift Dzire',
#  '2016 Toyota Camry',
#  '2011 Volkswagen Polo',
#  '2010 Honda Civic',
#  '2013 Hyundai Verna',
#  '2018 Hyundai Eon',
#  '2014 Maruti Swift',
#  '2011 Hyundai i20',
#  '2013 Maruti Swift Dzire',
#  '2012 Hyundai i20',
#  '2016 Maruti Ertiga',
#  '2018 Tata Tiago',
#  '2018 Volkswagen Vento',
#  '2018 Tata Tiago',
#  '2019 Renault Kwid',
#  '2012 Volkswagen Polo',
#  '2013 Hyundai Verna',
#  '2016 Renault Kwid',
#  '2021 Renault Kwid',
#  '2020 Maruti XL6',
#  '2014 Maruti Swift Dzire',
#  '2016 Toyota Camry',
#  '2011 Volkswagen Polo',
#  '2010 Honda Civic',
#  '2013 Hyundai Verna',
#  '2018 Hyundai Eon',
#  '2014 Maruti Swift',
#  '2011 Hyundai i20',
#  '2013 Maruti Swift Dzire',
#  '2012 Hyundai i20',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF3=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Bangalore','Price':price})
DF3
# Out:
#           Brand         Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0        Maruti      [Ertiga]      2016        85,970 km  Diesel
# 1          Tata       [Tiago]      2018        79,628 km  Petrol    Automatic
# 2    Volkswagen       [Vento]      2018        43,521 km  Petrol    Automatic
# 3          Tata       [Tiago]      2018        28,154 km  Petrol       Manual
# 4       Renault        [Kwid]      2019        13,588 km  Petrol    Automatic
# ..          ...           ...       ...              ...     ...          ...
# 495      Maruti       [Dzire]      2017        58,062 km  Petrol       Manual
# 496     Hyundai         [i10]      2013        53,594 km  Petrol       Manual
# 497     Renault        [Kwid]      2017        33,348 km  Petrol       Manual
# 498     Hyundai       [Creta]      2018        15,653 km  Petrol
# 499     Hyundai  [Elite, i20]      2019        15,752 km  Petrol       Manual
#
#     Number_of_owners   Location       Price
# ...

# %%
DF3.to_csv('car_data_3.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # hyb

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[4]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2017 Hyundai Elite i20',
#  '2017 Volkswagen Ameo',
#  '2013 Maruti Alto K10',
#  '2013 Maruti Alto K10',
#  '2011 Maruti Alto',
#  '2018 Hyundai Verna',
#  '2019 Renault Kwid',
#  '2018 Mahindra KUV 100 NXT',
#  '2017 Datsun Go',
#  '2013 Hyundai i10',
#  '2010 Maruti Alto',
#  '2021 Maruti Dzire',
#  '2021 Toyota Glanza',
#  '2019 Hyundai Creta',
#  '2019 Renault Kwid',
#  '2017 Skoda Rapid',
#  '2017 Tata Tiago',
#  '2015 Maruti Alto 800',
#  '2017 Maruti Wagon R 1.0',
#  '2019 Volkswagen Polo',
#  '2017 Hyundai Elite i20',
#  '2017 Volkswagen Ameo',
#  '2013 Maruti Alto K10',
#  '2013 Maruti Alto K10',
#  '2011 Maruti Alto',
#  '2018 Hyundai Verna',
#  '2019 Renault Kwid',
#  '2018 Mahindra KUV 100 NXT',
#  '2017 Datsun Go',
#  '2013 Hyundai i10',
#  '2010 Maruti Alto',
#  '2021 Maruti Dzire',
#  '2021 Toyota Glanza',
#  '2019 Hyundai Creta',
#  '2019 Renault Kwid',
#  '2017 Skoda Rapid',
#  '2017 Tata Tiago',
#  '2015 Maruti Alto 800',
#  '2017 Maruti Wagon R 1.0',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF4=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Hyderabad','Price':price})
DF4
# Out:
#           Brand         Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0       Hyundai  [Elite, i20]      2017        66,077 km  Petrol       Manual
# 1    Volkswagen        [Ameo]      2017        33,018 km  Petrol       Manual
# 2        Maruti   [Alto, K10]      2013        82,141 km  Petrol       Manual
# 3        Maruti   [Alto, K10]      2013        78,575 km  Petrol       Manual
# 4        Maruti        [Alto]      2011        36,830 km  Petrol       Manual
# ..          ...           ...       ...              ...     ...          ...
# 495      Maruti     [Celerio]      2021        17,760 km  Petrol
# 496      Maruti       [IGNIS]      2018        54,509 km  Petrol
# 497      Datsun    [Redi, Go]      2021         9,845 km  Petrol       Manual
# 498        Ford    [Ecosport]      2020        13,318 km  Petrol    Automatic
# 499      Maruti       [IGNIS]      2019        54,821 km  Petrol
#
#     Number_of_owners   Location      Price
# ...

# %%
DF4.to_csv('car_data_4.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Ahmedabad

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[5]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
car_name
# Out:
# ['2016 Mahindra XUV500',
#  '2011 Maruti Swift',
#  '2016 Renault Kwid',
#  '2021 Renault Kwid',
#  '2017 Hyundai Grand i10',
#  '2019 Hyundai Grand i10',
#  '2016 Hyundai Elite i20',
#  '2018 Maruti Swift',
#  '2018 Maruti Baleno',
#  '2017 Jeep Compass',
#  '2022 Renault TRIBER',
#  '2012 Maruti Swift',
#  '2018 Maruti Dzire',
#  '2021 Maruti Baleno',
#  '2018 Tata Tiago',
#  '2021 Maruti Swift',
#  '2022 Renault TRIBER',
#  '2018 Maruti Vitara Brezza',
#  '2018 Hyundai Xcent',
#  '2015 Hyundai Elite i20',
#  '2016 Mahindra XUV500',
#  '2011 Maruti Swift',
#  '2016 Renault Kwid',
#  '2021 Renault Kwid',
#  '2017 Hyundai Grand i10',
#  '2019 Hyundai Grand i10',
#  '2016 Hyundai Elite i20',
#  '2018 Maruti Swift',
#  '2018 Maruti Baleno',
#  '2017 Jeep Compass',
#  '2022 Renault TRIBER',
#  '2012 Maruti Swift',
#  '2018 Maruti Dzire',
#  '2021 Maruti Baleno',
#  '2018 Tata Tiago',
#  '2021 Maruti Swift',
#  '2022 Renault TRIBER',
#  '2018 Maruti Vitara Brezza',
# ...

# %%
len(car_name)
# Out:
# 420

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF5=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Ahmedabad','Price':price})
DF5
# Out:
#         Brand         Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0    Mahindra      [XUV500]      2016        69,471 km  Diesel    Automatic
# 1      Maruti       [Swift]      2011        53,025 km  Petrol       Manual
# 2     Renault        [Kwid]      2016        90,197 km  Petrol    Automatic
# 3     Renault        [Kwid]      2021         3,068 km  Petrol    Automatic
# 4     Hyundai  [Grand, i10]      2017        60,716 km  Petrol       Manual
# ..        ...           ...       ...              ...     ...          ...
# 415    Nissan     [MAGNITE]      2021        11,353 km  Petrol
# 416    Maruti        [Alto]      2021        33,066 km     CNG       Manual
# 417    Maruti      [Baleno]      2016        69,730 km  Petrol       Manual
# 418    Maruti        [Alto]      2022        10,341 km  Petrol
# 419    Maruti       [Swift]      2020        58,180 km  Petrol       Manual
#
#     Number_of_owners   Location      Price
# ...

# %%
DF5.to_csv('car_data_5.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Gurgaon

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[6]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2019 Jeep Compass',
#  '2019 Jeep Compass',
#  '2020 Skoda Rapid',
#  '2021 Hyundai VENUE',
#  '2013 Maruti Ritz',
#  '2014 Volkswagen Polo',
#  '2021 Renault Kwid',
#  '2013 Honda City',
#  '2017 Jeep Compass',
#  '2014 Honda City',
#  '2014 Hyundai Grand i10',
#  '2014 Honda City',
#  '2021 Toyota YARIS',
#  '2014 Hyundai Grand i10',
#  '2018 Honda City',
#  '2012 Maruti Ritz',
#  '2020 Renault Kwid',
#  '2012 Honda Brio',
#  '2014 Hyundai Grand i10',
#  '2013 Honda Brio',
#  '2019 Jeep Compass',
#  '2019 Jeep Compass',
#  '2020 Skoda Rapid',
#  '2021 Hyundai VENUE',
#  '2013 Maruti Ritz',
#  '2014 Volkswagen Polo',
#  '2021 Renault Kwid',
#  '2013 Honda City',
#  '2017 Jeep Compass',
#  '2014 Honda City',
#  '2014 Hyundai Grand i10',
#  '2014 Honda City',
#  '2021 Toyota YARIS',
#  '2014 Hyundai Grand i10',
#  '2018 Honda City',
#  '2012 Maruti Ritz',
#  '2020 Renault Kwid',
#  '2012 Honda Brio',
#  '2014 Hyundai Grand i10',
#  '2013 Honda Brio',
#  '2021 Maruti Baleno',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF6=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Gurgaon ','Price':price})
DF6
# Out:
#        Brand               Model Manu_Year Driven_kilometer    Fuel  \
# 0       Jeep           [Compass]      2019        23,690 km  Petrol
# 1       Jeep           [Compass]      2019        47,040 km  Diesel
# 2      Skoda             [Rapid]      2020        18,953 km  Petrol
# 3    Hyundai             [VENUE]      2021         6,059 km  Petrol
# 4     Maruti              [Ritz]      2013        61,753 km  Petrol
# ..       ...                 ...       ...              ...     ...
# 495  Renault              [Kwid]      2017        66,802 km  Petrol
# 496   Maruti            [Baleno]      2019        33,836 km  Petrol
# 497   Maruti            [Baleno]      2020        50,112 km  Petrol
# 498  Hyundai        [Elite, i20]      2019        49,538 km  Petrol
# 499  Hyundai  [GRAND, I10, NIOS]      2021        33,231 km     CNG
#
#     Transmission Number_of_owners  Location      Price
# 0      Automatic        1st Owner  Gurgaon
# 1         Manual        1st Owner  Gurgaon
# ...

# %%
DF6.to_csv('car_data_6.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # chennai

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[7]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2015 Volkswagen Vento',
#  '2020 Maruti Swift',
#  '2017 Datsun Go',
#  '2020 Datsun Redi Go',
#  '2016 Honda City',
#  '2012 Maruti Wagon R 1.0',
#  '2019 Maruti IGNIS',
#  '2014 Maruti Wagon R 1.0',
#  '2018 Hyundai Elite i20',
#  '2017 Maruti Alto K10',
#  '2010 Maruti Alto K10',
#  '2017 Hyundai Grand i10',
#  '2019 Honda Amaze',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR',
#  '2017 Jeep Compass',
#  '2013 Hyundai i20',
#  '2015 Hyundai Eon',
#  '2021 Nissan MAGNITE',
#  '2020 Maruti S PRESSO',
#  '2015 Volkswagen Vento',
#  '2020 Maruti Swift',
#  '2017 Datsun Go',
#  '2020 Datsun Redi Go',
#  '2016 Honda City',
#  '2012 Maruti Wagon R 1.0',
#  '2019 Maruti IGNIS',
#  '2014 Maruti Wagon R 1.0',
#  '2018 Hyundai Elite i20',
#  '2017 Maruti Alto K10',
#  '2010 Maruti Alto K10',
#  '2017 Hyundai Grand i10',
#  '2019 Honda Amaze',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR',
#  '2017 Jeep Compass',
#  '2013 Hyundai i20',
#  '2015 Hyundai Eon',
#  '2021 Nissan MAGNITE',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF7=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'chennai','Price':price})
DF7
# Out:
#           Brand       Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0    Volkswagen     [Vento]      2015        61,978 km  Petrol    Automatic
# 1        Maruti     [Swift]      2020        19,329 km  Petrol       Manual
# 2        Datsun        [Go]      2017        26,883 km  Petrol       Manual
# 3        Datsun  [Redi, Go]      2020        21,157 km  Petrol       Manual
# 4         Honda      [City]      2016        77,885 km  Petrol       Manual
# ..          ...         ...       ...              ...     ...          ...
# 495         KIA    [SELTOS]      2022        12,447 km  Diesel       Manual
# 496      Maruti    [Baleno]      2016        60,207 km  Diesel
# 497       Honda     [Amaze]      2014        82,339 km  Petrol       Manual
# 498      Maruti      [Eeco]      2019        54,717 km  Petrol       Manual
# 499     Hyundai     [Verna]      2017        49,042 km  Petrol    Automatic
#
#     Number_of_owners Location      Price
# ...

# %%
DF7.to_csv('car_data_7.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # pune

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[8]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2015 Volkswagen Vento',
#  '2020 Maruti Swift',
#  '2017 Datsun Go',
#  '2020 Datsun Redi Go',
#  '2016 Honda City',
#  '2012 Maruti Wagon R 1.0',
#  '2019 Maruti IGNIS',
#  '2014 Maruti Wagon R 1.0',
#  '2018 Hyundai Elite i20',
#  '2017 Maruti Alto K10',
#  '2010 Maruti Alto K10',
#  '2017 Hyundai Grand i10',
#  '2019 Honda Amaze',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR',
#  '2017 Jeep Compass',
#  '2013 Hyundai i20',
#  '2015 Hyundai Eon',
#  '2021 Nissan MAGNITE',
#  '2020 Maruti S PRESSO',
#  '2015 Volkswagen Vento',
#  '2020 Maruti Swift',
#  '2017 Datsun Go',
#  '2020 Datsun Redi Go',
#  '2016 Honda City',
#  '2012 Maruti Wagon R 1.0',
#  '2019 Maruti IGNIS',
#  '2014 Maruti Wagon R 1.0',
#  '2018 Hyundai Elite i20',
#  '2017 Maruti Alto K10',
#  '2010 Maruti Alto K10',
#  '2017 Hyundai Grand i10',
#  '2019 Honda Amaze',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR',
#  '2017 Jeep Compass',
#  '2013 Hyundai i20',
#  '2015 Hyundai Eon',
#  '2021 Nissan MAGNITE',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF8=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Pune','Price':price})
DF8
# Out:
#        Brand               Model Manu_Year Driven_kilometer    Fuel  \
# 0    Hyundai               [i10]      2014        24,876 km  Petrol
# 1     Maruti              [Alto]      2019        13,757 km  Petrol
# 2    Renault              [Kwid]      2020        27,596 km  Petrol
# 3    Hyundai      [Santro, Xing]      2011        65,759 km  Petrol
# 4    Hyundai               [i10]      2014        22,457 km  Petrol
# ..       ...                 ...       ...              ...     ...
# 495    Honda              [City]      2014        73,751 km  Petrol
# 496   Maruti     [Wagon, R, 1.0]      2017        32,853 km     CNG
# 497  Hyundai        [Grand, i10]      2018        15,485 km  Petrol
# 498   Maruti     [Wagon, R, 1.0]      2018        20,583 km     CNG
# 499  Hyundai  [GRAND, I10, NIOS]      2021        12,101 km     CNG
#
#     Transmission Number_of_owners Location      Price
# 0                       1st Owner     Pune  ₹3,91,000
# ...

# %%
DF8.to_csv('car_data_8.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Noida

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[9]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2020 Hyundai Grand i10',
#  '2011 Maruti Wagon R 1.0',
#  '2014 Honda Amaze',
#  '2012 Honda City',
#  '2018 Hyundai Grand i10',
#  '2011 Hyundai i10',
#  '2021 Toyota Innova Crysta',
#  '2020 KIA SONET',
#  '2015 Toyota Camry',
#  '2018 Maruti Ciaz',
#  '2019 Honda Amaze',
#  '2022 Skoda KUSHAQ',
#  '2015 Honda Amaze',
#  '2011 Maruti Wagon R 1.0',
#  '2021 KIA SONET',
#  '2010 Maruti Swift',
#  '2011 Maruti Swift',
#  '2018 Honda Amaze',
#  '2017 Honda City',
#  '2017 Hyundai Grand i10',
#  '2020 Hyundai Grand i10',
#  '2011 Maruti Wagon R 1.0',
#  '2014 Honda Amaze',
#  '2012 Honda City',
#  '2018 Hyundai Grand i10',
#  '2011 Hyundai i10',
#  '2021 Toyota Innova Crysta',
#  '2020 KIA SONET',
#  '2015 Toyota Camry',
#  '2018 Maruti Ciaz',
#  '2019 Honda Amaze',
#  '2022 Skoda KUSHAQ',
#  '2015 Honda Amaze',
#  '2011 Maruti Wagon R 1.0',
#  '2021 KIA SONET',
#  '2010 Maruti Swift',
#  '2011 Maruti Swift',
#  '2018 Honda Amaze',
#  '2017 Honda City',
#  '2017 Hyundai Grand i10',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF9=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Noida','Price':price})
DF9
# Out:
#        Brand            Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0    Hyundai     [Grand, i10]      2020        13,851 km  Petrol       Manual
# 1     Maruti  [Wagon, R, 1.0]      2011        33,043 km  Petrol       Manual
# 2      Honda          [Amaze]      2014        61,575 km     CNG    Automatic
# 3      Honda           [City]      2012        62,560 km  Petrol       Manual
# 4    Hyundai     [Grand, i10]      2018        11,881 km  Petrol       Manual
# ..       ...              ...       ...              ...     ...          ...
# 495   Maruti   [New, Wagon-R]      2021        27,228 km     CNG       Manual
# 496   Maruti   [New, Wagon-R]      2020        33,988 km     CNG       Manual
# 497   Maruti        [Celerio]      2017        48,341 km     CNG       Manual
# 498  Renault           [Kwid]      2018        35,793 km  Petrol       Manual
# 499   Maruti   [New, Wagon-R]      2020        45,640 km     CNG       Manual
#
# ...

# %%
DF9.to_csv('car_data_9.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Ghaziabad

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[10]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 500

# %%
car_name
# Out:
# ['2016 Maruti Ciaz',
#  '2016 Maruti Baleno',
#  '2015 Toyota Corolla Altis',
#  '2017 Hyundai Grand i10',
#  '2019 Maruti XL6',
#  '2014 Maruti Ertiga',
#  '2010 Honda City',
#  '2019 Mahindra XUV500',
#  '2019 Mahindra Bolero',
#  '2020 Maruti Swift',
#  '2016 Honda City',
#  '2021 Hyundai AURA',
#  '2016 Maruti Ciaz',
#  '2018 Maruti Vitara Brezza',
#  '2018 Maruti Swift',
#  '2017 Volkswagen Polo',
#  '2019 Maruti Swift',
#  '2019 Maruti Swift',
#  '2018 Tata NEXON',
#  '2016 Hyundai Elite i20',
#  '2016 Maruti Ciaz',
#  '2016 Maruti Baleno',
#  '2015 Toyota Corolla Altis',
#  '2017 Hyundai Grand i10',
#  '2019 Maruti XL6',
#  '2014 Maruti Ertiga',
#  '2010 Honda City',
#  '2019 Mahindra XUV500',
#  '2019 Mahindra Bolero',
#  '2020 Maruti Swift',
#  '2016 Honda City',
#  '2021 Hyundai AURA',
#  '2016 Maruti Ciaz',
#  '2018 Maruti Vitara Brezza',
#  '2018 Maruti Swift',
#  '2017 Volkswagen Polo',
#  '2019 Maruti Swift',
#  '2019 Maruti Swift',
#  '2018 Tata NEXON',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF10=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Ghaziabad','Price':price})
DF10
# Out:
#        Brand             Model Manu_Year Driven_kilometer    Fuel  \
# 0     Maruti            [Ciaz]      2016      1,00,441 km  Petrol
# 1     Maruti          [Baleno]      2016        52,927 km  Petrol
# 2     Toyota  [Corolla, Altis]      2015      1,00,530 km  Petrol
# 3    Hyundai      [Grand, i10]      2017        17,815 km  Petrol
# 4     Maruti             [XL6]      2019        15,561 km  Petrol
# ..       ...               ...       ...              ...     ...
# 495   Maruti            [Ciaz]      2018        21,880 km  Petrol
# 496   Toyota  [Corolla, Altis]      2014        89,959 km  Petrol
# 497    Honda           [Amaze]      2016        26,527 km  Petrol
# 498   Maruti         [Celerio]      2018        27,138 km  Petrol
# 499   Maruti          [Baleno]      2019        11,825 km  Petrol
#
#     Transmission Number_of_owners   Location       Price
# 0         Manual        1st Owner  Ghaziabad   ₹5,19,000
# 1         Manual        1st Owner  Ghaziabad   ₹5,14,000
# ...

# %%
DF10.to_csv('car_data_10.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Lucknow

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[11]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 152

# %%
car_name
# Out:
# ['2015 Maruti Alto 800',
#  '2020 Tata ALTROZ',
#  '2022 Tata TIGOR',
#  '2020 Maruti New Wagon-R',
#  '2017 Maruti Swift',
#  '2016 Hyundai Elite i20',
#  '2019 Maruti Alto K10',
#  '2020 Maruti Alto',
#  '2018 Hyundai Elite i20',
#  '2017 Toyota Fortuner',
#  '2021 Maruti Baleno',
#  '2021 Hyundai VENUE',
#  '2019 Mahindra TUV300',
#  '2015 Audi A6',
#  '2021 Mahindra XUV 3OO',
#  '2018 Honda Brio',
#  '2018 Hyundai Creta',
#  '2019 Maruti Alto K10',
#  '2017 Maruti Baleno',
#  '2022 Tata Tiago',
#  '2015 Maruti Alto 800',
#  '2020 Tata ALTROZ',
#  '2022 Tata TIGOR',
#  '2020 Maruti New Wagon-R',
#  '2017 Maruti Swift',
#  '2016 Hyundai Elite i20',
#  '2019 Maruti Alto K10',
#  '2020 Maruti Alto',
#  '2018 Hyundai Elite i20',
#  '2017 Toyota Fortuner',
#  '2021 Maruti Baleno',
#  '2021 Hyundai VENUE',
#  '2019 Mahindra TUV300',
#  '2015 Audi A6',
#  '2021 Mahindra XUV 3OO',
#  '2018 Honda Brio',
#  '2018 Hyundai Creta',
#  '2019 Maruti Alto K10',
#  '2017 Maruti Baleno',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF11=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Lucknow','Price':price})
DF11
# Out:
#        Brand           Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0     Maruti     [Alto, 800]      2015        65,245 km     CNG       Manual
# 1       Tata        [ALTROZ]      2020        31,828 km  Petrol       Manual
# 2       Tata         [TIGOR]      2022         4,725 km     CNG
# 3     Maruti  [New, Wagon-R]      2020        79,667 km     CNG       Manual
# 4     Maruti         [Swift]      2017      6,80,010 km  Diesel       Manual
# ..       ...             ...       ...              ...     ...          ...
# 147   Maruti        [Baleno]      2017        67,741 km     CNG       Manual
# 148   Maruti  [New, Wagon-R]      2020        90,293 km     CNG       Manual
# 149  Hyundai    [Grand, i10]      2020        10,871 km  Petrol       Manual
# 150   Maruti          [Ciaz]      2021        33,731 km  Petrol       Manual
# 151   Maruti        [Baleno]      2018        59,767 km  Petrol       Manual
#
#     Number_of_owners Location      Price
# ...

# %%
DF11.to_csv('car_data_11.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Kolkata

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[13]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 232

# %%
 car_name
# Out:
# ['2015 Maruti Wagon R 1.0',
#  '2019 Skoda Rapid',
#  '2016 Hyundai Verna',
#  '2013 Maruti Swift Dzire',
#  '2019 Maruti Alto 800',
#  '2018 Hyundai Verna',
#  '2014 Toyota Etios',
#  '2013 Maruti Zen Estilo',
#  '2013 Maruti Wagon R 1.0',
#  '2014 Toyota Etios',
#  '2010 Hyundai i10',
#  '2020 KIA SELTOS',
#  '2015 Maruti Baleno',
#  '2013 Maruti Zen Estilo',
#  '2013 Hyundai Grand i10',
#  '2018 Hyundai Verna',
#  '2010 Hyundai i20',
#  '2014 Volkswagen Polo',
#  '2016 Hyundai i20 Active',
#  '2014 Maruti Wagon R Stingray',
#  '2015 Maruti Wagon R 1.0',
#  '2019 Skoda Rapid',
#  '2016 Hyundai Verna',
#  '2013 Maruti Swift Dzire',
#  '2019 Maruti Alto 800',
#  '2018 Hyundai Verna',
#  '2014 Toyota Etios',
#  '2013 Maruti Zen Estilo',
#  '2013 Maruti Wagon R 1.0',
#  '2014 Toyota Etios',
#  '2010 Hyundai i10',
#  '2020 KIA SELTOS',
#  '2015 Maruti Baleno',
#  '2013 Maruti Zen Estilo',
#  '2013 Hyundai Grand i10',
#  '2018 Hyundai Verna',
#  '2010 Hyundai i20',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF12=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Kolkata','Price':price})
DF12
# Out:
#         Brand            Model Manu_Year Driven_kilometer    Fuel  \
# 0      Maruti  [Wagon, R, 1.0]      2015        44,280 km  Petrol
# 1       Skoda          [Rapid]      2019        41,464 km  Petrol
# 2     Hyundai          [Verna]      2016        73,749 km  Petrol
# 3      Maruti   [Swift, Dzire]      2013        84,041 km  Diesel
# 4      Maruti      [Alto, 800]      2019        29,095 km  Petrol
# ..        ...              ...       ...              ...     ...
# 227  Mahindra        [Scorpio]      2021        26,805 km  Diesel
# 228     Honda          [Amaze]      2020        25,685 km  Petrol
# 229    Maruti      [Alto, 800]      2013        45,643 km  Petrol
# 230      Ford       [Ecosport]      2014        38,203 km  Petrol
# 231  Mahindra        [Scorpio]      2020        32,327 km  Diesel
#
#     Transmission Number_of_owners Location       Price
# 0         Manual        1st Owner  Kolkata   ₹3,27,000
# 1         Manual        1st Owner  Kolkata   ₹7,09,000
# ...

# %%
DF12.to_csv('car_data_12.csv')

# %%
driver.close()

# %%
# lets import nec library
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#lets first connect webdriver
driver=webdriver.Chrome('chromedriver')

#maximize the automated window
driver.maximize_window()

# %%
#open the link 
url='https://www.cars24.com/?utm_keyword=cars%2024&utm_matchtype=&utm_device=c&adgroup_id=&campaign_id=17427920397&utm_source=google&utm_medium=adwords&utm_campaign=mobileonlymumbai&utm_keyword=&utm_matchtype=&utm_device=c&adgroup_id=43576377485&campaign_id=906967653&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE&gclid=CjwKCAiArNOeBhAHEiwAze_nKDiHrPDj2tJdcr11ceURUgHgVyKNrIU-3i0H8Syc70VEFXAMpxR67xoCVKcQAvD_BwE'
driver.get(url)

# %%
# click search button (find all cars)
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/button[1]')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button') #manually
search_btn.click()

# %% [markdown]
# # Jaipur

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[12]/a')
search_btn.click()

# %%
#5000 time we scroll down for getting atleast 500 comments

for _ in range(5000):

    driver.execute_script("window.scrollBy(0,5000)")

# %%
#car_name
car_name=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    car_name.append(name.text)

# %%
len(car_name)
# Out:
# 159

# %%
car_name
# Out:
# ['2016 Hyundai Elite i20',
#  '2014 Hyundai Elite i20',
#  '2017 Hyundai Xcent',
#  '2019 Maruti Eeco',
#  '2020 Renault TRIBER',
#  '2019 Honda Amaze',
#  '2019 Maruti Dzire',
#  '2015 Maruti Swift',
#  '2016 Maruti Wagon R 1.0',
#  '2021 Tata NEXON',
#  '2018 Maruti Celerio X',
#  '2017 Honda WR-V',
#  '2017 Honda City',
#  '2018 Hyundai Elite i20',
#  '2022 Maruti Celerio',
#  '2014 Hyundai i10',
#  '2018 Hyundai Creta',
#  '2019 Tata TIAGO NRG',
#  '2019 Hyundai Grand i10',
#  '2021 Hyundai NEW I20',
#  '2016 Hyundai Elite i20',
#  '2014 Hyundai Elite i20',
#  '2017 Hyundai Xcent',
#  '2019 Maruti Eeco',
#  '2020 Renault TRIBER',
#  '2019 Honda Amaze',
#  '2019 Maruti Dzire',
#  '2015 Maruti Swift',
#  '2016 Maruti Wagon R 1.0',
#  '2021 Tata NEXON',
#  '2018 Maruti Celerio X',
#  '2017 Honda WR-V',
#  '2017 Honda City',
#  '2018 Hyundai Elite i20',
#  '2022 Maruti Celerio',
#  '2014 Hyundai i10',
#  '2018 Hyundai Creta',
#  '2019 Tata TIAGO NRG',
#  '2019 Hyundai Grand i10',
# ...

# %%
#manu_year
manu_year=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    manu_year.append(name.text.split(' ')[0])
    


#Brand
Brand=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Brand.append(name.text.split(' ')[1])
    
    
#Model
Model=[]
names = driver.find_elements(By.XPATH,'//h3[@class="_3FpCg"]')

for name in names[0:500]:

    Model.append(name.text.split(' ')[2:])
    
    
#trans
trans=[]
names = driver.find_elements(By.XPATH,'//p[@class="cvakB"]/span')

for name in names[0:500]:

    trans.append(name.text)
    
    
#owner
owner=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    owner.append(name.text.split('\n')[1])
    
    
#km_driven
km_driven=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    km_driven.append(name.text.split('\n')[0])
    
    
#fuel
fuel=[]
names = driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')

for name in names[0:500]:

    fuel.append(name.text.split('\n')[2])
    
    
#price
price=[]
names = driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')

for name in names[0:500]:

    price.append(name.text)

# %%
#creating dataframe 

DF13=pd.DataFrame({'Brand':Brand,'Model':Model,'Manu_Year':manu_year, 'Driven_kilometer':km_driven ,'Fuel':fuel ,'Transmission':trans, 'Number_of_owners':owner ,'Location':'Jaipu','Price':price})
DF13
# Out:
#        Brand         Model Manu_Year Driven_kilometer    Fuel Transmission  \
# 0    Hyundai  [Elite, i20]      2016        95,605 km  Petrol       Manual
# 1    Hyundai  [Elite, i20]      2014        79,718 km  Petrol       Manual
# 2    Hyundai       [Xcent]      2017        29,902 km  Petrol       Manual
# 3     Maruti        [Eeco]      2019        13,003 km  Petrol       Manual
# 4    Renault      [TRIBER]      2020        65,811 km  Petrol       Manual
# ..       ...           ...       ...              ...     ...          ...
# 154   Maruti        [Eeco]      2020        55,212 km  Petrol       Manual
# 155   Maruti        [Eeco]      2021        25,909 km  Petrol       Manual
# 156  Hyundai  [Elite, i20]      2019        35,518 km  Petrol       Manual
# 157   Maruti      [Baleno]      2018        17,493 km  Petrol       Manual
# 158   Maruti        [Alto]      2019        63,488 km     CNG       Manual
#
#     Number_of_owners Location      Price
# ...

# %%
DF13.to_csv('car_data_13.csv')

# %%
driver.close()
