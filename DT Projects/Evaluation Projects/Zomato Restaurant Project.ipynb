# %% [markdown]
# # 1st Model [predicting : 1) Average Cost for two]

# %%
#lets import necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('zomato.csv' , encoding='iso-8859-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1 = pd.read_excel('Country-Code.xlsx')
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df2 = pd.merge(df,df1,on='Country Code',how='left')
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# ## Pre processing

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ### Using simple imputer to impute null values

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent', missing_values=np.nan)
imputer = imputer.fit(df[[ 'Cuisines']])
df[['Cuisines' ]] = imputer.transform(df[['Cuisines']])
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ### Dropping Duplicate Values

# %%
#  check  the duplicate
duplicate = df2[df2.duplicated()]
print("Duplicate Rows :")
 
#  Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []
#
# [0 rows x 22 columns]

# %%
# delete duplicate
df2.drop_duplicates(inplace=True)

# %%
#  check  the duplicate
duplicate = df2[df2.duplicated()]
print("Duplicate Rows :")
 
#  Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## EDA and Visualization

# %%
# Seeing which car sold most
plt.figure(figsize=(20,5))
sns.countplot(x='Currency' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Currency'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64
# ********************

# %% [markdown]
# ## From the above Countplot, we can observe rupees are mostly used as the most use currency.

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Has Table booking' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Has Table booking'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64
# ********************

# %% [markdown]
# ## From the above count plot, we can observe only 1158 Restaurant has a reservation for a table.

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Has Online delivery' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Has Online delivery'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64
# ********************

# %% [markdown]
# ## From the above count plot, we can observe only 2451 Restaurant has an option for online delivery.

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Is delivering now' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Is delivering now'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64
# ********************

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Price range' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Price range'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64
# ********************

# %% [markdown]
# ## From the above count plot, we can observe the price range for food number  1st is high, followed by 2nd and 3rd, and 4th.

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Seeing which car sold most
plt.figure(figsize=(15,5))
sns.countplot(x='Aggregate rating' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Aggregate rating'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64
# ********************

# %% [markdown]
# ## From the above count plot, we observe the average rating is about the 3.1 to 3.3 range but we also observe 2148 people have not given a rating to the Restaurant.

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Rating text' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Rating text'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64
# ********************

# %% [markdown]
# ## From the count plot, we observe the average rating for all restaurants is Average.

# %%
df3 = df2.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df3
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ## Ratings
#
# Rating 0 — White — Not rated
#
# Rating 1.8 to 2.4 — Red — Poor
#
# Rating 2.5 to 3.4 — Orange — Average
#
# Rating 3.5 to 3.9 — Yellow — Good
#
# Rating 4.0 to 4.4 — Green — Very Good
#
# Rating 4.5 to 4.9 — Dark Green — Excellent

# %%
# Seeing which car sold most
plt.figure(figsize=(7,5))
sns.countplot(x='Rating color' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df['Rating color'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64
# ********************

# %% [markdown]
# ## From the above table and graph, the average rating for color is orange which means the rating is from 2.5 to 3.4, and the food rating is average.

# %%
# Seeing which car sold most
plt.figure(figsize=(15,5))
sns.countplot(x='Country' , data=df2)
plt.title('types of the model')
print('*'*20)
print(df2['Country'].value_counts())
print('*'*20)
plt.show()
# Out:
# ********************
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
# ********************

# %% [markdown]
# ## From the above count plot, we observe that most restaurant in the dataset is mostly in India followed by the united states.

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df4=pd.DataFrame().assign(country=df2['Country'],agg_rat=df2['Aggregate rating'])
df4
# Out:
#           country  agg_rat
# 0     Phillipines      4.8
# 1     Phillipines      4.5
# 2     Phillipines      4.4
# 3     Phillipines      4.9
# 4     Phillipines      4.8
# ...           ...      ...
# 9546       Turkey      4.1
# 9547       Turkey      4.2
# 9548       Turkey      3.7
# 9549       Turkey      4.0
# 9550       Turkey      4.0
#
# [9551 rows x 2 columns]

# %%
Countries_Total_df = df4.groupby('country').sum()

# %%
top_10 = Countries_Total_df.sort_values(by='agg_rat',ascending =False)[:1]

# %%
Countries_Total_df.sort_values(by='agg_rat',ascending =False)[:10] #top 10 resto according to high agg rating
# Out:
#                 agg_rat
# country
# India           21831.8
# United States    1737.9
# United Kingdom    327.0
# UAE               254.0
# South Africa      252.6
# Brazil            225.8
# New Zealand       170.5
# Turkey            146.2
# Phillipines        98.3
# Indonesia          90.2

# %%
Countries_Total_df.sort_values(by='agg_rat',ascending =False)[:10].plot(kind='bar')
plt.xlabel("Top 10 Countries")
plt.ylabel("Highest rated")
plt.title("Top 10 Countries VS Aggregate Rating")
plt.show()

# %% [markdown]
# ## From the above Bar graph, we observe only India is the country that rated most of the restaurants followed by the united states and the united kingdom.

# %%
#Create a pie chart for cities distribution
Country_values=df2.Country.value_counts().values
Country_labels=df2.Country.value_counts().index

# %%
plt.figure(figsize=(15,15))
plt.pie(Country_values[:5],labels=Country_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## The above pie chart shows the top 5 countries where zomato businesses spread more in which country. first is India with 93.17% followed by the United States with 4.67% then the united kingdom, Brazil and at last UAE with 0.86%, 0.65% both for Brazil and UAE.

# %%
India = df2[(df2.Country == 'India')]
df4=India
df4.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
#Create a pie chart for cities distribution
India_values=df4.City.value_counts().values
India_labels=df4.City.value_counts().index

# %%
plt.figure(figsize=(15,15))
plt.pie(India_values[:5],labels=India_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## The above pie chart shows the top 5 cities of India that contribute most to the zomato first is new Delhi with 68.87%, followed by Gurgaon with 14.07% followed by Noida with 13.59%.

# %%
#Create a pie chart for cities distribution
India_values=df4.Cuisines.value_counts().values
India_labels=df4.Cuisines.value_counts().index

# %%
plt.figure(figsize=(15,15))
plt.pie(India_values[:5],labels=India_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## The above pie chart shows the top 5 cuisines of India according to Zomato is the best with the help of ratings first is North-Indian food with 37.91%, followed by North-Indian, Chinese with 20.70%, and fast food with 14.09%.

# %%
us = df2[(df2.Country == 'United States')]
df4=us
df4
# Out:
#      Restaurant ID                           Restaurant Name  Country Code  \
# 82        17284404               Austin's BBQ and Oyster Bar           216
# 83        17284203                       BJ's Country Buffet           216
# 84        17284105                             Cookie Shoppe           216
# 85        17284302             El Vaquero Mexican Restaurant           216
# 86        17284397            Elements Coffee Co - Northwest           216
# ..             ...                                       ...           ...
# 558       17697389                       The Screaming Eagle           216
# 559       17697424                             The Thai Bowl           216
# 560       17697332                Tokyo Japanese Steak House           216
# 561       17694056  Theo Yianni's Authentic Greek Restaurant           216
# 562       17559793                 Fishpatrick's Crabby Cafe           216
#
#                City                                      Address  \
# ...

# %%
#Create a pie chart for cities distribution
us_values=df4.City.value_counts().values
us_labels=df4.City.value_counts().index

# %%
plt.figure(figsize=(15,15))
plt.pie(us_values[:5],labels=us_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## The above pie chart shows top 5 cities of the United states that contribute most to the zomato and what we observe is that all the top 5 cities contribute equal in amount.

# %%
#Create a pie chart for cities distribution
us_values=df4.Cuisines.value_counts().values
us_labels=df4.Cuisines.value_counts().index

# %%
plt.figure(figsize=(15,15))
plt.pie(us_values[:5],labels=us_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## The above pie chart shows top 5 cuisines in the United States according to the zomato is the best with the help of ratings first is Mexican food with 37.31%, followed by American with 23.88%, and BBQ and Chinese which contribute the same at 13.43% and last is seafood with11.94%.

# %%
plt.scatter(df['Average Cost for two'],df['Aggregate rating'])
plt.xlabel('Average Cost for two')
plt.ylabel('Aggregate rating')
plt.title('Average Cost for two vs Aggregate rating')
plt.show()

# %% [markdown]
# ## So from the above scatter plot, we observe there is no relationship between Aggregate rating and Average Cost for two.

# %%
df2.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df2.drop(['Restaurant ID', 'Country Code' , 'Address','Locality', 'Locality Verbose' , 'Switch to order menu'],axis=1,inplace = True) #unwanted

# %%
df2.shape
# Out:
# (9551, 16)

# %% [markdown]
# ## Applying Label Encoder to categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df13=le.fit_transform(df['Has Table booking'])
pd.Series(df13)
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 9546    0
# 9547    0
# 9548    0
# 9549    0
# 9550    0
# Length: 9551, dtype: int32

# %%
df2['Has Table booking']=df13

# %%
df13=le.fit_transform(df['Has Online delivery'])
pd.Series(df13)
df2['Has Online delivery']=df13

# %%
df13=le.fit_transform(df['Is delivering now'])
pd.Series(df13)
df2['Is delivering now']=df13

# %%
df13=le.fit_transform(df['Rating color'])
pd.Series(df13)
df2['Rating color']=df13

# %%
df13=le.fit_transform(df['Rating text'])
pd.Series(df13)
df2['Rating text']=df13

# %%
df13=le.fit_transform(df['Currency'])
pd.Series(df13)
df2['Currency']=df13

# %%
df13=le.fit_transform(df['Restaurant Name'])
pd.Series(df13)
df2['Restaurant Name']=df13

# %%
df13=le.fit_transform(df['City'])
pd.Series(df13)
df2['City']=df13

# %%
df13=le.fit_transform(df2['Country'])
pd.Series(df13)
df2['Country']=df13

# %%
df13=le.fit_transform(df['Cuisines'])
pd.Series(df13)
df2['Cuisines']=df13

# %%
df2.dtypes
# Out:
# Restaurant Name           int32
# City                      int32
# Longitude               float64
# Latitude                float64
# Cuisines                  int32
# Average Cost for two      int64
# Currency                  int32
# Has Table booking         int32
# Has Online delivery       int32
# Is delivering now         int32
# Price range               int64
# Aggregate rating        float64
# Rating color              int32
# Rating text               int32
# Votes                     int64
# Country                   int32
# dtype: object

# %%
df2.describe()
# Out:
#        Restaurant Name         City    Longitude     Latitude     Cuisines  \
# count      9551.000000  9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586    78.301434    64.126574    25.854381   989.461732
# std        2142.917876    23.198915    41.467058    11.007935   514.176108
# min           0.000000     0.000000  -157.948486   -41.330428     0.000000
# 25%        1777.500000    76.000000    77.081343    28.478713   497.000000
# 50%        3595.000000    88.000000    77.191964    28.570469  1127.000000
# 75%        5485.500000    88.000000    77.282006    28.642758  1353.500000
# max        7445.000000   140.000000   174.832089    55.976980  1824.000000
#
#        Average Cost for two     Currency  Has Table booking  \
# count           9551.000000  9551.000000        9551.000000
# mean            1199.210763     3.977699           0.121244
# std            16121.183073     0.914242           0.326428
# ...

# %% [markdown]
# ## Observations
#
# 1] The dataset contains 9551 rows and 21 columns in which there are only 9 null values in Cuisines column and we treat it with simple imputer
#
# 2] we found some duplicate values and we drop it
#
# 3] We observe avegarge cost for two columns , votes has high Standard deviation and maximum values.

# %% [markdown]
# ## Plotting the heatmap to observe Co-relation

# %%
corr=df2.corr()
corr.shape
# Out:
# (16, 16)

# %%
corr=df2.corr().abs()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ## From the above heatmap, we observe country vs Longitude having high co-relation and therefore we suspect that there is the problem of multi-colinearity existing and all features are slightly positively and negatively co-related with our label average for two.

# %%
df2.columns
# Out:
# Index(['Restaurant Name', 'City', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
plt.scatter(df2['Longitude'],df2['Country'])
plt.xlabel('Longitude')
plt.ylabel('Country')
plt.title('Longitude vs Country')
plt.show()

# %% [markdown]
# ## For 2nd proof, we plot a scatter plot to observe any kind of trend and to confirm our multi-collinearity but we don't find any trend so we don't have any multi-collinearity problem.

# %% [markdown]
# ## Plotting Histogram plot to see how data is distributed on an interval scale.

# %%
# now lets see how data is distributed for every column 

plt.figure(figsize=(20,15) , facecolor = 'yellow')
plotnumber = 1

for column in df2:
    if plotnumber <= 16:
        ax = plt.subplot(4,4,plotnumber)
        sns.histplot (df2[column])
        plt.xlabel(column , fontsize=10)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ##  Plotting Distribution plot to see how data is distributed

# %%
# now lets see how data is distributed for every column 

plt.figure(figsize=(20,15) , facecolor = 'yellow')
plotnumber = 1

for column in df2:
    if plotnumber <= 16:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot (df2[column])
        plt.xlabel(column , fontsize=10)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ## From the above histogram and distribution pot, we observe dataset is having a large amount of skewness.

# %% [markdown]
# ## Seperating Features and label

# %%
X = df2.drop(['Average Cost for two'],axis = 1)
y = df2['Average Cost for two']

# %%
# checking data types of X 
X.dtypes
# Out:
# Restaurant Name          int32
# City                     int32
# Longitude              float64
# Latitude               float64
# Cuisines                 int32
# Currency                 int32
# Has Table booking        int32
# Has Online delivery      int32
# Is delivering now        int32
# Price range              int64
# Aggregate rating       float64
# Rating color             int32
# Rating text              int32
# Votes                    int64
# Country                  int32
# dtype: object

# %% [markdown]
# ## Plotting Scatter plot to see realtion between feature and label

# %%
# so find relationship between feature(X) and label(y) by visulization using scatter plot

plt.figure(figsize = (20,15) , facecolor = 'red')
plotnumber = 1

for column in X:   #here feature is new X so X
    if plotnumber <= 15:
        ax = plt.subplot(3,5,plotnumber)
        plt.scatter(X[column] , y)
        plt.xlabel(column , fontsize = 10)
        plt.ylabel('W' , fontsize = 10)
    plotnumber += 1
plt.show()

# %% [markdown]
# ## Plotting Regression plot to see realtion between feature and label

# %%
# now lets see how data is distributed for every column 

plt.figure(figsize=(20,15) , facecolor = 'yellow')
plotnumber = 1

for column in X:
    if plotnumber <= 15:
        ax = plt.subplot(3,5,plotnumber)
        sns.regplot (X[column],y)
        plt.xlabel(column , fontsize=10)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ## From the scatter plot and regression plot, we observe All of the features are neutral in the relationship to our label only votes show a small amount of positively co-related to our feature.

# %% [markdown]
# ## Plotting Box plot to see outliers are present are not

# %%
plt.figure(figsize=(20,15) , facecolor = 'red')
graph = 1

for column in X:
    
    if graph <= 15:
        plt.subplot (3,5,graph)
        ax = sns.boxplot(X[column])
        plt.xlabel(column , fontsize = 20)
        
    graph += 1
    
plt.show()

# %% [markdown]
# ## From the boxplot, we observe a large number of outliers as we observe in the distribution plot that there is a large amount of skewness.

# %% [markdown]
# ## Treating outliers with Z-score method

# %%
# we will go with 3 std
# from scipy import stats

from scipy.stats import zscore

# %%
# new code for deleting outlier here we take std = 3
z_score = zscore(df2)
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 2.5 ).all(axis=1)

df2 = df2[filtering_entry]

df2.describe()
# Out:
#        Restaurant Name         City    Longitude     Latitude    Cuisines  \
# count      7274.000000  7274.000000  7274.000000  7274.000000  7274.00000
# mean       3605.614792    81.345615    72.575603    26.348486  1001.06915
# std        2133.601469    16.582760    18.721647     7.263723   512.54515
# min           0.000000    24.000000     0.000000     0.000000     0.00000
# 25%        1734.000000    88.000000    77.099029    28.496939   497.00000
# 50%        3509.500000    88.000000    77.202795    28.572237  1235.00000
# 75%        5443.500000    88.000000    77.286772    28.639579  1348.00000
# max        7441.000000   134.000000   103.862120    30.914057  1821.00000
#
#        Average Cost for two     Currency  Has Table booking  \
# count           7274.000000  7274.000000             7274.0
# mean             466.890982     3.994501                0.0
# std              353.621142     0.104735                0.0
# ...

# %% [markdown]
# ## Scaling the data

# %%
#scale our data using standard sclar
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_scaled=scalar.fit_transform(X)

# %% [markdown]
# ## Checking for the multicollinearity Using VIF

# %%
# now we check for multicolinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()  #creating empty dataframe

vif['vif']=[variance_inflation_factor(X_scaled , i) for i in range(X_scaled.shape[1])]  


# for above code first it will execute for statement and shape[1] give all columns and store in i then it will pass to vif 
##  in that we already have X_scaled so it will compare feature vs feature

vif['features']=X.columns  # seperate column for column features

vif
# Out:
#          vif             features
# 0   1.007839      Restaurant Name
# 1   1.065187                 City
# 2   3.430290            Longitude
# 3   1.379408             Latitude
# 4   1.043187             Cuisines
# 5   1.296271             Currency
# 6   1.454808    Has Table booking
# 7   1.158979  Has Online delivery
# 8   1.013082    Is delivering now
# 9   1.896324          Price range
# 10  1.798200     Aggregate rating
# 11  1.227280         Rating color
# 12  1.343632          Rating text
# 13  1.244440                Votes
# 14  3.641983              Country

# %% [markdown]
# ## From VIF we observe there is no sign of multico-linearity so for now we keep all the features

# %% [markdown]
# ## Finding correlation between feature n lable using CORR method

# %%
#  (code type      --   feature corrwith label)

df2.drop('Average Cost for two' , axis =1 ).corrwith (df2['Average Cost for two'])
# Out:
# Restaurant Name        0.042129
# City                  -0.087049
# Longitude              0.017868
# Latitude              -0.028157
# Cuisines              -0.015257
# Currency               0.046204
# Has Table booking           NaN
# Has Online delivery    0.138867
# Is delivering now           NaN
# Price range            0.800571
# Aggregate rating       0.314546
# Rating color          -0.070563
# Rating text            0.059777
# Votes                  0.377954
# Country               -0.046204
# dtype: float64

# %%
# convert above numbers into graph for better understanding
df2.drop('Average Cost for two' , axis = 1).corrwith (df2['Average Cost for two']).plot(kind = 'bar' , grid=True , figsize = (10,7) , title = 'correlation with target')

plt.show()

# %% [markdown]
# ## Feature selection with SelectKBest

# %%
# selecting 10 best feature 
from sklearn.feature_selection import SelectKBest , f_classif

# %%
X = df2.drop(['Average Cost for two'],axis = 1)
y = df2['Average Cost for two']

# %%
#select best feature
# selecting 14 best feature 
from sklearn.feature_selection import SelectKBest , f_classif

best_feature = SelectKBest(score_func=f_classif , k=10)

fit = best_feature.fit(X,y)

df2_scores = pd.DataFrame(fit.scores_)

df2_column = pd.DataFrame(X.columns)

feature_scores = pd.concat ([df2_column , df2_scores ] , axis =1)

feature_scores.columns=['Feature_Name' , 'Scores']

print (feature_scores.nlargest (10 , 'Scores'))
# Out:
#            Feature_Name       Scores
# 9           Price range  1959.845004
# 14              Country   272.226665
# 5              Currency   272.226665
# 13                Votes    32.152691
# 10     Aggregate rating    21.389986
# 7   Has Online delivery    15.505494
# 12          Rating text     5.959173
# 3              Latitude     5.038072
# 4              Cuisines     3.884844
# 11         Rating color     3.790842

# %%
df2.columns
# Out:
# Index(['Restaurant Name', 'City', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ##  we selected top 10 feature from feature selection technique

# %%
#Model BUilding
new_X = df2[['Country','Votes','Rating text','Has Online delivery','Longitude', 'Latitude','Price range','Currency', 'Has Table booking','Aggregate rating']]

# %%
#standardizing the data

scalar=StandardScaler()
x_scalar=scalar.fit_transform(new_X)

# %%
new_X
# Out:
#       Country  Votes  Rating text  Has Online delivery   Longitude   Latitude  \
# 456         8     34            0                    0  103.860005   1.282661
# 457         8     33            5                    0  103.859422   1.285477
# 458         8     33            2                    0  103.840360   1.279420
# 459         8     34            0                    0  103.841669   1.280503
# 460         8     35            2                    0  103.853605   1.293221
# ...       ...    ...          ...                  ...         ...        ...
# 9271        3    193            2                    0   83.361377  17.764287
# 9272        3     85            2                    0    0.000000   0.000000
# 9273        3    172            5                    0   83.315281  17.719539
# 9274        3     74            2                    0   83.336840  17.721182
# 9275        3    316            5                    0   83.314942  17.721119
#
# ...

# %%
y.shape
# Out:
# (7274,)

# %% [markdown]
# #  Linear Regression Model

# %%
#lets import necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Best Random State

# %%
#Best Random State
MaxAccu=0
MaxRS=0

for i in range (0,200):
    X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    regression=LinearRegression()
    regression.fit(X_train,y_train)
    
    pred=regression.predict(X_train)
    training=regression.score(X_train,y_train)
    print ('Training Score' , training*100 , 'RandomState' ,i)
    
    y_pred=regression.predict(X_test)
    testing=regression.score(X_test,y_test)
    print ('Testing Score' , testing*100 , 'RandomState' ,i)
    print('\n')
    
    
    if testing>MaxAccu:
        MaxAccu=testing
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , i)
# Out:
# Training Score 67.4897984288624 RandomState 0
# Testing Score 70.75214690597642 RandomState 0
#
#
# MAXINING TESTING SCORE 70.75214690597642 ON RANDOM STATE OF 0
# Training Score 66.79485560720055 RandomState 1
# Testing Score 73.88478043124158 RandomState 1
#
#
# MAXINING TESTING SCORE 73.88478043124158 ON RANDOM STATE OF 1
# Training Score 68.679690119802 RandomState 2
# Testing Score 67.0203490405025 RandomState 2
#
#
# Training Score 67.55854721348295 RandomState 3
# Testing Score 70.10475836229108 RandomState 3
#
#
# Training Score 69.58271895894839 RandomState 4
# Testing Score 64.74069755291335 RandomState 4
#
#
# Training Score 67.58694374371848 RandomState 5
# Testing Score 70.4528325796217 RandomState 5
#
#
# Training Score 71.26660083869886 RandomState 6
# Testing Score 61.65156608640922 RandomState 6
#
#
# Training Score 66.37021322394008 RandomState 7
# Testing Score 74.61924491535949 RandomState 7
#
#
# MAXINING TESTING SCORE 74.61924491535949 ON RANDOM STATE OF 7
# ...

# %%
print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , MaxRS)
# Out:
# MAXINING TESTING SCORE 77.21894276394438 ON RANDOM STATE OF 24

# %% [markdown]
# ### Training the model

# %%
#splliting our data into train test split and randomstate 6
X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=24)

# %%
#Training the data on Linear Regression Model
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#training score
regression.score(X_train,y_train)
# Out:
# 0.6580198421334141

# %%
#testing score
regression.score(X_test,y_test)
# Out:
# 0.7721894276394439

# %% [markdown]
# ## Model Score
# * Training Score = 65.80198421334141 %
# * Testing Score = 77.21894276394439 %

# %%
y_pred=regression.predict(X_test)
y_pred
# Out:
# array([ 681.98499969,  258.11087516,  245.0074843 , ...,  688.67374083,
#        1087.81027674,  663.11372311])

# %%
# how our pred vs actual look like in graph 
plt.scatter(y_test , y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual VS Model Prediction')
plt.show()

# %%
#error in terms of numbers
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
# again predict 
y_pred = regression.predict(X_test)

# %% [markdown]
# ##  Checking MAE , MSE & RMSE scores

# %%
#MAE
mean_absolute_error(y_test,y_pred)
# Out:
# 114.2991063133406

# %%
#MSE
mean_squared_error(y_test,y_pred)
# Out:
# 23947.538678430123

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 154.74992303206525

# %% [markdown]
# ## Scores
# * MAE SCORE = 114.2991063133406
# * MSE SCORE = 23947.538678430123
# * RMSE SCORE = 154.74992303206525

# %% [markdown]
# ## LASSO MODEL

# %%
#import library
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

# %%
##### LASSO MODEL######

lasscv = LassoCV(alphas = None , max_iter = 100, normalize = True)

lasscv.fit(X_train , y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
# best aplha parameter
alpha = lasscv.alpha_
alpha
# Out:
# 0.0038700520323397196

# %%
# now we have best parametr noe train according to it
lasso_reg = Lasso(alpha)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0038700520323397196)

# %%
# now check r2 score
lasso_reg.score(X_test,y_test)
# Out:
# 0.7718084113801815

# %% [markdown]
# ## RIDGE MODEL

# %%
############ RIDGE MODEL#########

ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01), normalize = True)
ridgecv.fit(X_train , y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
# best aplha parameter
alpha = ridgecv.alpha_
alpha
# Out:
# 0.001

# %%
# now we have best parametr noe train according to it
ridge_reg = Ridge(alpha)
ridge_reg.fit (X_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
# now check r2 score
ridge_reg.score(X_test,y_test)
# Out:
# 0.7718054968328696

# %% [markdown]
# ## SCORES
# * LASSO SCORES = 77.18084113801815 %
# * RIDGE SCORES = 77.18054968328696 %

# %% [markdown]
# ## Cross-Validation For Linear Regression Model

# %%
#Cross Vaildation
training=regression.score(X_train,y_train)
testing=regression.score(X_test,y_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(regression,X,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and the R2 score for Training is {training} and R2 score for the Testing is{testing}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.5931287697333236 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# At cross fold 3 the cv score is 0.5773958910687221 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# At cross fold 4 the cv score is 0.5910540033839771 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# At cross fold 5 the cv score is 0.6336793375169174 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# At cross fold 6 the cv score is 0.6540033690239745 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# At cross fold 7 the cv score is 0.6634325116200924 and the R2 score for Training is 0.6580198421334141 and R2 score for the Testing is0.7721894276394439
#
#
# ...

# %% [markdown]
# ## Cross-Validation Score
# * Cross-Validation Score at cv=9 is 66.50823341282436 %
# * R2 Score for Training Score = 65.80198421334141 %
# * R2 Score for Testing Testing Score = 77.21894276394439 %

# %% [markdown]
# # AdaBoostRegressor Model

# %%
# IMPORT LIBRARY 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Best Random State

# %%
#Best Random State
MaxAccu=0
MaxRS=0

for i in range (0,200):
    X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    ada=AdaBoostRegressor()
    ada.fit(X_train,y_train)
    
    pred=ada.predict(X_train)
    training=ada.score(X_train,y_train)
    print ('Training Score' , training*100 , 'RandomState' ,i)
    
    y_pred=ada.predict(X_test)
    testing=ada.score(X_test,y_test)
    print ('Testing Score' , testing*100 , 'RandomState' ,i)
    print('\n')
    
    
    if testing>MaxAccu:
        MaxAccu=testing
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , i)
# Out:
# Training Score 79.12499927518968 RandomState 0
# Testing Score 76.29140460086586 RandomState 0
#
#
# MAXINING TESTING SCORE 76.29140460086586 ON RANDOM STATE OF 0
# Training Score 79.81746415888131 RandomState 1
# Testing Score 77.60055856955633 RandomState 1
#
#
# MAXINING TESTING SCORE 77.60055856955633 ON RANDOM STATE OF 1
# Training Score 80.28213798260064 RandomState 2
# Testing Score 77.3687899701347 RandomState 2
#
#
# Training Score 82.54859015883522 RandomState 3
# Testing Score 79.69128768889973 RandomState 3
#
#
# MAXINING TESTING SCORE 79.69128768889973 ON RANDOM STATE OF 3
# Training Score 83.07994662031857 RandomState 4
# Testing Score 76.91156235580048 RandomState 4
#
#
# Training Score 80.12031262708322 RandomState 5
# Testing Score 78.65599498132492 RandomState 5
#
#
# Training Score 83.87888097484486 RandomState 6
# Testing Score 77.965842227135 RandomState 6
#
#
# Training Score 81.6229170859745 RandomState 7
# Testing Score 75.78893951253475 RandomState 7
#
#
# ...

# %%
print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , MaxRS)
# Out:
# MAXINING TESTING SCORE 81.83818319804917 ON RANDOM STATE OF 77

# %% [markdown]
# ### Training the model

# %%
#splliting our data into train test split and randomstate 8
X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=77)

# %%
# adaboost inilize
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
ada.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
 # model prediction on training dataset
y_pred = ada.predict(X_train)

# %%
accuracy = metrics.r2_score (y_train , y_pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8235746821317773

# %%
# model prediction on testing datadet
pred = ada.predict(X_test)

# %%
accuracy = metrics.r2_score(y_test,pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8212961334849045

# %% [markdown]
# ## Model Scores
# * Training Score = 82.35746821317773 %
# * testing Score = 82.12961334849045 %

# %% [markdown]
# ## Hyperparameter Tuning for Ada Boost

# %%
### HYPERPARAMETER TUNING ###
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'n_estimators': [45,47,53,55,60,70] , 
          'learning_rate':[0.25,0.30,0.40]}

# %%
rnd_srch = RandomizedSearchCV(AdaBoostRegressor() , cv=5 , param_distributions=params , n_jobs=-1)

# %%
rnd_srch.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(), n_jobs=-1,
#                    param_distributions={'learning_rate': [0.25, 0.3, 0.4],
#                                         'n_estimators': [45, 47, 53, 55, 60,
#                                                          70]})

# %%
rnd_srch.best_params_
# Out:
# {'n_estimators': 70, 'learning_rate': 0.25}

# %%
rnd_srch.best_estimator_
# Out:
# AdaBoostRegressor(learning_rate=0.25, n_estimators=70)

# %%
ada = AdaBoostRegressor(learning_rate=0.25, n_estimators=70)
ada.fit(X_train,y_train)

pred=ada.predict(X_train)
print('====Training Score====')
print(metrics.r2_score(y_train,pred))
y_pred = ada.predict(X_test)

print ('=== Testing Score ===')
print (metrics.r2_score(y_test,y_pred))
# Out:
# ====Training Score====
# 0.8005367691005614
# === Testing Score ===
# 0.810145135668396

# %% [markdown]
# ## Model Score after Hyperparameter Tuning
# * Training Score = 80.05367691005614 %
# * Testing Score = 81.0145135668396 %

# %% [markdown]
# ## Cross Validation for Ada Boost

# %%
#Cross Vaildation
training=ada.score(X_train,y_train)
testing=ada.score(X_test,y_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(ada,X,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and the R2 score for Training is {training} and R2 score for the Testing is{testing}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.6753766601086917 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# At cross fold 3 the cv score is 0.6961254284331523 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# At cross fold 4 the cv score is 0.683983439112418 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# At cross fold 5 the cv score is 0.7106999608025306 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# At cross fold 6 the cv score is 0.7121529094195226 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# At cross fold 7 the cv score is 0.69399277079439 and the R2 score for Training is 0.8005367691005614 and R2 score for the Testing is0.810145135668396
#
#
# ...

# %% [markdown]
# ## Cross-Validation Score
# * Cross-Validation Score at cv=6 is 71.21529094195226 %
# * R2 Score for Training Score = 80.05367691005614 %
# * R2 Score for Testing Testing Score = 81.0145135668396 %

# %% [markdown]
# # RandomForestRegressor Model

# %%
#import necessary library

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Best Random State

# %%
#Best Random State
MaxAccu=0
MaxRS=0

for i in range (0,200):
    X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    rf=RandomForestRegressor()
    rf.fit(X_train,y_train)
    
    pred=rf.predict(X_train)
    training=rf.score(X_train,y_train)
    print ('Training Score' , training*100 , 'RandomState' ,i)
    
    y_pred=rf.predict(X_test)
    testing=rf.score(X_test,y_test)
    print ('Testing Score' , testing*100 , 'RandomState' ,i)
    print('\n')
    
    
    if testing>MaxAccu:
        MaxAccu=testing
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , i)
# Out:
# Training Score 96.89149039422973 RandomState 0
# Testing Score 80.68562587306974 RandomState 0
#
#
# MAXINING TESTING SCORE 80.68562587306974 ON RANDOM STATE OF 0
# Training Score 96.6404677863405 RandomState 1
# Testing Score 81.06220341987334 RandomState 1
#
#
# MAXINING TESTING SCORE 81.06220341987334 ON RANDOM STATE OF 1
# Training Score 96.70741252465731 RandomState 2
# Testing Score 81.31244501773452 RandomState 2
#
#
# MAXINING TESTING SCORE 81.31244501773452 ON RANDOM STATE OF 2
# Training Score 96.63536974578957 RandomState 3
# Testing Score 78.94238728737459 RandomState 3
#
#
# Training Score 97.11002081019878 RandomState 4
# Testing Score 75.18341283173284 RandomState 4
#
#
# Training Score 96.55397796381692 RandomState 5
# Testing Score 82.26956503982127 RandomState 5
#
#
# MAXINING TESTING SCORE 82.26956503982127 ON RANDOM STATE OF 5
# Training Score 97.06705180574366 RandomState 6
# Testing Score 76.12928531005049 RandomState 6
#
#
# ...

# %%
print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , MaxRS)
# Out:
# MAXINING TESTING SCORE 84.40153171872804 ON RANDOM STATE OF 199

# %% [markdown]
# ### Training the model

# %%
#splliting our data into train test split and randomstate 8
X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=199)

# %%
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
 # model prediction on training dataset
y_pred = rf.predict(X_train)

# %%
accuracy = metrics.r2_score (y_train , y_pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.9642241369823317

# %%
# model prediction on testing datadet
pred = rf.predict(X_test)

# %%
accuracy = metrics.r2_score(y_test,pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8409987356874755

# %% [markdown]
# ## Model Score
# * Training Score = 96.42241369823317 %
# * Testing Score = 84.09987356874755 %

# %% [markdown]
# ## Hyperparameter tuning for Random Forest

# %%
# RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# define parameters
parameters={'criterion':['mse','mae','poisson'],
           'max_features':['auto','sqrt','log2'],
           'min_samples_split':[1,11],
           'max_depth':[1,15],
           'min_samples_leaf':[1,7]}

# %%
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae', 'poisson'],
#                          'max_depth': [1, 15],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 7],
#                          'min_samples_split': [1, 11]})

# %%
#print best parameters
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 11}

# %%
#reassign best parameters
rf=RandomForestRegressor(criterion= 'mae', max_depth= 15, max_features= 'auto', min_samples_leaf= 1, min_samples_split= 11)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(criterion='mae', max_depth=15, max_features='auto',
#                       min_samples_split=11)

# %%
from sklearn.metrics import r2_score
print ('Training R2 Score: ' ,rf.score(X_train,y_train)*100)
# Out:
# Training R2 Score:  86.80471517100948

# %%
pred_decision=rf.predict(X_test)
rfs = r2_score(y_test,pred_decision)

# %%
print('Testing R2 Score:' , rfs*100)
# Out:
# Testing R2 Score: 84.92430817912894

# %% [markdown]
# ## Model Score after Hyperparameter Tuning
# * Training Score = 86.80471517100948 %
# * Testing Score = 84.92430817912894 %

# %% [markdown]
# ## Cross Validation for Random Forest

# %%
#Cross Vaildation
training=rf.score(X_train,y_train)
testing=rf.score(X_test,y_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rf,X,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and the R2 score for Training is {training} and R2 score for the Testing is{testing}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.6998410660358336 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# At cross fold 3 the cv score is 0.7159328487191118 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# At cross fold 4 the cv score is 0.7138949132890529 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# At cross fold 5 the cv score is 0.74503684336328 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# At cross fold 6 the cv score is 0.7474217374179252 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# At cross fold 7 the cv score is 0.726095125011877 and the R2 score for Training is 0.8680471517100947 and R2 score for the Testing is0.8492430817912895
#
#
# ...

# %% [markdown]
# ##  Cross-Validation Score
# * Cross-Validation Score at cv=6 is 74.74217374179252 %
# * R2 Score for Training Score = 86.80471517100947 %
# * R2 Score for Testing Testing Score = 84.92430817912895 %

# %% [markdown]
# # GradientBoostingRegressor Model

# %%
# import library

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectPercentile , chi2
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# ### Best Random State

# %%
#Best Random State
MaxAccu=0
MaxRS=0

for i in range (0,200):
    X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    gbdt=GradientBoostingRegressor()
    gbdt.fit(X_train,y_train)
    
    pred=gbdt.predict(X_train)
    training=gbdt.score(X_train,y_train)
    print ('Training Score' , training*100 , 'RandomState' ,i)
    
    y_pred=gbdt.predict(X_test)
    testing=gbdt.score(X_test,y_test)
    print ('Testing Score' , testing*100 , 'RandomState' ,i)
    print('\n')
    
    
    if testing>MaxAccu:
        MaxAccu=testing
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , i)
# Out:
# Training Score 87.72789780353156 RandomState 0
# Testing Score 82.36629402861945 RandomState 0
#
#
# MAXINING TESTING SCORE 82.36629402861945 ON RANDOM STATE OF 0
# Training Score 87.2009356725834 RandomState 1
# Testing Score 83.34225930344982 RandomState 1
#
#
# MAXINING TESTING SCORE 83.34225930344982 ON RANDOM STATE OF 1
# Training Score 86.9715470332333 RandomState 2
# Testing Score 80.72107305082963 RandomState 2
#
#
# Training Score 87.23967689408816 RandomState 3
# Testing Score 83.05026231295693 RandomState 3
#
#
# Training Score 87.59483586976027 RandomState 4
# Testing Score 78.02510336620439 RandomState 4
#
#
# Training Score 87.7896815200329 RandomState 5
# Testing Score 80.68909150387282 RandomState 5
#
#
# Training Score 86.67090663833379 RandomState 6
# Testing Score 79.76528507604907 RandomState 6
#
#
# Training Score 88.02784512796224 RandomState 7
# Testing Score 81.13400923115506 RandomState 7
#
#
# Training Score 87.82262434361637 RandomState 8
# ...

# %%
print('MAXINING TESTING SCORE' , MaxAccu*100 , 'ON RANDOM STATE OF' , MaxRS)
# Out:
# MAXINING TESTING SCORE 85.11551676840914 ON RANDOM STATE OF 199

# %% [markdown]
# ### Training the model

# %%
#splliting our data into train test split and randomstate 8
X_train,X_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=199)

# %%
# initiate GradientBoostingClassifier
gbdt= GradientBoostingRegressor()
gbdt.fit(X_train , y_train)
# Out:
# GradientBoostingRegressor()

# %%
 # model prediction on training dataset
y_pred = gbdt.predict(X_train)

# %%
accuracy = metrics.r2_score (y_train , y_pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8729430119244637

# %%
# model prediction on testing datadet
pred = gbdt.predict(X_test)

# %%
accuracy = metrics.r2_score(y_test,pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8518106879291678

# %% [markdown]
# ## Model Score
# * Training Score = 87.29430119244637 %
# * Testing Score = 85.18106879291678 %

# %% [markdown]
# ## Hyperparameter tuning for GradientBoostingRegressor

# %%
# HYPERPARAMETER TUNING #
from sklearn.model_selection import GridSearchCV

# %%
# internally it will use decision tree as name suggest GBDT and here we are going to add one new parameter i.e learning rate 

grid_params = {'max_depth' : range(1,8),
               'min_samples_split': range(2,12,1),
               'learning_rate': np.arange(0.1 , 0.9),
               'n_estimators': [90,95,100,105,110]}

# %%
grid = GridSearchCV(GradientBoostingRegressor() , param_grid = grid_params , n_jobs = -1)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': array([0.1]),
#                          'max_depth': range(1, 8),
#                          'min_samples_split': range(2, 12),
#                          'n_estimators': [90, 95, 100, 105, 110]})

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 2,
#  'min_samples_split': 10,
#  'n_estimators': 105}

# %%
gbdt_clf = GradientBoostingRegressor(learning_rate= 0.1,
 max_depth= 10,
 min_samples_split= 5,
 n_estimators= 105)

# %%
gbdt_clf.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, min_samples_split=5, n_estimators=105)

# %%
 # model prediction on training dataset
y_pred = gbdt_clf.predict(X_train)

# %%
accuracy = metrics.r2_score (y_train , y_pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.9794476382226457

# %%
# model prediction on testing datadet
pred = gbdt_clf.predict(X_test)

# %%
accuracy = metrics.r2_score(y_test,pred)
print ('R Squared Score : ' , accuracy)
# Out:
# R Squared Score :  0.8291738427817752

# %% [markdown]
# ## Model Score after Hyperparameter Tuning
# * Training Score = 97.94476382226457 %
# * Testing Score = 82.91738427817752 %

# %% [markdown]
# ## Cross Vaildation for GradientBoostingRegressor

# %%
#Cross Vaildation
training=gbdt_clf.score(X_train,y_train)
testing=gbdt_clf.score(X_test,y_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(gbdt_clf,X,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and the R2 score for Training is {training} and R2 score for the Testing is{testing}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.6858173743670591 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# At cross fold 3 the cv score is 0.6708358209385231 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# At cross fold 4 the cv score is 0.6803824473576687 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# At cross fold 5 the cv score is 0.709921890680631 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# At cross fold 6 the cv score is 0.7091602780475036 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# At cross fold 7 the cv score is 0.6940094520056146 and the R2 score for Training is 0.9794476382226457 and R2 score for the Testing is0.8291738427817752
#
#
# ...

# %% [markdown]
# ## Cross-Validation Score
# * Cross-Validation Score at cv=6 is 70.91602780475036 %
# * R2 Score for Training Score = 97.94476382226457 %
# * R2 Score for Testing Testing Score = 82.91738427817752 %

# %% [markdown]
# # # All model score after hyperparameter tuning
#
# ** Linear Regression Model
#
#      Cross-Validation Score at cv=9 is 66.50823341282436 %
#
#      R2 Score for Training Score = 65.80198421334141 %
#
#      R2 Score for Testing Testing Score = 77.21894276394439 %
#
#
# ** AdaBoostRegressor Model
#
#     Cross-Validation Score at cv=6 is 71.21529094195226 %
#
#     R2 Score for Training Score = 80.05367691005614 %
#
#     R2 Score for Testing Testing Score = 81.0145135668396 %
#
#
# ** RandomForestRegressor Model
#
#     Cross-Validation Score at cv=6 is 74.74217374179252 %
#
#     R2 Score for Training Score = 86.80471517100947 %
#
#     R2 Score for Testing Testing Score = 84.92430817912895 %
#
#
# ** GradientBoostingRegressor Model
#
#     Cross-Validation Score at cv=6 is 70.91602780475036 %
#
#     R2 Score for Training Score = 97.94476382226457 %
#
#     R2 Score for Testing Testing Score = 82.91738427817752 %

# %% [markdown]
# ### From All model Scores Random Forest is best suit for this perticular model so saving the Random Forest Model

# %% [markdown]
# ## Saving the Best Model

# %%
# now we save this is modeland transfer to other by using pickel

#first save this model to the local file system 
import pickle
pickle.dump(rf , open ('reg_model' , 'wb'))

# %% [markdown]
# # 2nd Model [predicting : 2) Price range]

# %% [markdown]
# ## Loading the dataset again

# %%
#lets import necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('zomato.csv' , encoding='iso-8859-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1 = pd.read_excel('Country-Code.xlsx')
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df2 = pd.merge(df,df1,on='Country Code',how='left')
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Pre Processing

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ### Imputing the Null value By simple Imputer

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent', missing_values=np.nan)
imputer = imputer.fit(df[[ 'Cuisines']])
df[['Cuisines' ]] = imputer.transform(df[['Cuisines']])
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df2.drop(['Restaurant ID', 'Country Code' , 'Address','Locality', 'Locality Verbose' , 'Switch to order menu'],axis=1,inplace = True) #unwanted

# %%
df2.shape
# Out:
# (9551, 16)

# %% [markdown]
# ## Dropping the duplicates

# %%
# delete duplicate
df2.drop_duplicates(inplace=True)

# %%
#  check  the duplicate
duplicate = df2[df2.duplicated()]
print("Duplicate Rows :")
# Out:
# Duplicate Rows :

# %% [markdown]
# ## Applying Label Encoder to categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df13=le.fit_transform(df2['Has Table booking'])
pd.Series(df13)
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 9543    0
# 9544    0
# 9545    0
# 9546    0
# 9547    0
# Length: 9548, dtype: int32

# %%
df2['Has Table booking']=df13

# %%
df13=le.fit_transform(df2['Has Online delivery'])
pd.Series(df13)
df2['Has Online delivery']=df13

# %%
df13=le.fit_transform(df2['Is delivering now'])
pd.Series(df13)
df2['Is delivering now']=df13

# %%
df13=le.fit_transform(df2['Rating color'])
pd.Series(df13)
df2['Rating color']=df13

# %%
df13=le.fit_transform(df2['Rating text'])
pd.Series(df13)
df2['Rating text']=df13

# %%
df13=le.fit_transform(df2['Currency'])
pd.Series(df13)
df2['Currency']=df13

# %%
df13=le.fit_transform(df2['Restaurant Name'])
pd.Series(df13)
df2['Restaurant Name']=df13

# %%
df13=le.fit_transform(df2['City'])
pd.Series(df13)
df2['City']=df13

# %%
df13=le.fit_transform(df2['Country'])
pd.Series(df13)
df2['Country']=df13

# %%
df13=le.fit_transform(df2['Cuisines'])
pd.Series(df13)
df2['Cuisines']=df13

# %%
df2.dtypes
# Out:
# Restaurant Name           int32
# City                      int32
# Longitude               float64
# Latitude                float64
# Cuisines                  int32
# Average Cost for two      int64
# Currency                  int32
# Has Table booking         int32
# Has Online delivery       int32
# Is delivering now         int32
# Price range               int64
# Aggregate rating        float64
# Rating color              int32
# Rating text               int32
# Votes                     int64
# Country                   int32
# dtype: object

# %% [markdown]
# ## Plotting the heatmap to observe Co-relation

# %%
corr=df2.corr()
corr.shape
# Out:
# (16, 16)

# %%
corr=df2.corr().abs()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ## From the above heatmap, we observe country vs Longitude having high co-relation and therefore we suspect that there is the problem of multi-colinearity existing and all features are slightly positively and negatively co-related with our label average for two. but from above model we observe there is no trend in between those 2 feature so there is no multi-colinearity but we will also check VIF.

# %% [markdown]
# ## Seperating Features and label

# %%
X = df2.drop(['Price range'],axis = 1)
y = df2['Price range']

# %% [markdown]
# ## Plotting Scatter plot to see realtion between feature and label

# %%
# so find relationship between feature(X) and label(y) by visulization using scatter plot

plt.figure(figsize = (20,15) , facecolor = 'red')
plotnumber = 1

for column in X:   #here feature is new X so X
    if plotnumber <= 15:
        ax = plt.subplot(3,5,plotnumber)
        plt.scatter(X[column] , y)
        plt.xlabel(column , fontsize = 10)
        plt.ylabel('W' , fontsize = 10)
    plotnumber += 1
plt.show()

# %% [markdown]
# ## Plotting Regression plot to see realtion between feature and label

# %%
# now lets see how data is distributed for every column 

plt.figure(figsize=(20,15) , facecolor = 'yellow')
plotnumber = 1

for column in X:
    if plotnumber <= 15:
        ax = plt.subplot(3,5,plotnumber)
        sns.regplot (X[column],y)
        plt.xlabel(column , fontsize=10)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ## From the above Scatter plot and Regression Plot, we observe all features contribute to predicting our label and all features are positively and negatively correlated to our label price range.

# %% [markdown]
# ## Plotting Box plot to see outliers are present are not

# %%
plt.figure(figsize=(20,15) , facecolor = 'red')
graph = 1

for column in X:
    
    if graph <= 15:
        plt.subplot (3,5,graph)
        ax = sns.boxplot(X[column])
        plt.xlabel(column , fontsize = 20)
        
    graph += 1
    
plt.show()

# %% [markdown]
# ## From the boxplot, we observe a large number of outliers are present in out dataset.

# %% [markdown]
# ## treating the outliers with Z-score method

# %%
# we will go with 3 std
# from scipy import stats

from scipy.stats import zscore

# %%
# new code for deleting outlier here we take std = 3
z_score = zscore(df2)
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 2.5 ).all(axis=1)

df2 = df2[filtering_entry]

df2.describe()
# Out:
#        Restaurant Name        City    Longitude     Latitude     Cuisines  \
# count      7271.000000  7271.00000  7271.000000  7271.000000  7271.000000
# mean       3606.387705    81.34782    72.594909    26.355428  1001.086783
# std        2133.682671    16.58162    18.686684     7.252015   512.548849
# min           0.000000    24.00000     0.000000     0.000000     0.000000
# 25%        1734.000000    88.00000    77.099096    28.497333   497.000000
# 50%        3515.000000    88.00000    77.202798    28.572237  1235.000000
# 75%        5444.500000    88.00000    77.286761    28.639593  1348.000000
# max        7441.000000   134.00000   103.862120    30.914057  1821.000000
#
#        Average Cost for two     Currency  Has Table booking  \
# count           7271.000000  7271.000000             7271.0
# mean             466.939211     3.994499                0.0
# std              353.683205     0.104756                0.0
# ...

# %% [markdown]
# ## Scaling the data

# %%
#scale our data using standard sclar
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_scaled=scalar.fit_transform(X)

# %% [markdown]
# ## Checking for the multicollinearity Using VIF

# %%
# now we check for multicolinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()  #creating empty dataframe

vif['vif']=[variance_inflation_factor(X_scaled , i) for i in range(X_scaled.shape[1])]  


# for above code first it will execute for statement and shape[1] give all columns and store in i then it will pass to vif 
##  in that we already have X_scaled so it will compare feature vs feature

vif['features']=X.columns  # seperate column for column features

vif
# Out:
#          vif              features
# 0   1.006640       Restaurant Name
# 1   1.064971                  City
# 2   3.444586             Longitude
# 3   1.314545              Latitude
# 4   1.040349              Cuisines
# 5   1.029443  Average Cost for two
# 6   1.292577              Currency
# 7   1.097668     Has Table booking
# 8   1.159417   Has Online delivery
# 9   1.012303     Is delivering now
# 10  1.605601      Aggregate rating
# 11  1.226838          Rating color
# 12  1.310472           Rating text
# 13  1.233203                 Votes
# 14  3.584262               Country

# %% [markdown]
# ## From VIF we observe there is no sign of multico-linearity so for now we keep all the features

# %% [markdown]
# ## finding correlation between feature n lable using CORR method

# %%
#  (code type      --   feature corrwith label)

df2.drop('Price range' , axis =1 ).corrwith (df2['Price range'])
# Out:
# Restaurant Name         0.055343
# City                   -0.067340
# Longitude               0.020297
# Latitude               -0.113789
# Cuisines               -0.004580
# Average Cost for two    0.800586
# Currency               -0.165316
# Has Table booking            NaN
# Has Online delivery     0.174409
# Is delivering now            NaN
# Aggregate rating        0.351018
# Rating color           -0.069831
# Rating text             0.063715
# Votes                   0.399673
# Country                 0.165316
# dtype: float64

# %%
# convert above numbers into graph for better understanding
df2.drop('Price range' , axis = 1).corrwith (df2['Price range']).plot(kind = 'bar' , grid=True , figsize = (10,7) , title = 'correlation with target')

plt.show()

# %% [markdown]
# ## Feature selection with SelectKBest

# %%
# selecting 10 best feature 
from sklearn.feature_selection import SelectKBest , f_classif

# %%
X = df2.drop(['Price range'],axis = 1)
y = df2['Price range']

# %%
#select best feature
# selecting 14 best feature 
from sklearn.feature_selection import SelectKBest , f_classif

best_feature = SelectKBest(score_func=f_classif , k=10)

fit = best_feature.fit(X,y)

df2_scores = pd.DataFrame(fit.scores_)

df2_column = pd.DataFrame(X.columns)

feature_scores = pd.concat ([df2_column , df2_scores ] , axis =1)

feature_scores.columns=['Feature_Name' , 'Scores']

print (feature_scores.nlargest (10 , 'Scores'))
# Out:
#             Feature_Name       Scores
# 5   Average Cost for two  5241.484999
# 13                 Votes   516.878241
# 10      Aggregate rating   349.876440
# 8    Has Online delivery   257.373829
# 14               Country   199.433435
# 6               Currency   199.433435
# 3               Latitude    62.029950
# 12           Rating text    57.332438
# 1                   City    15.735625
# 11          Rating color    12.992267

# %% [markdown]
# ## we selected top 10 feature from feature selection technique

# %%
#Model BUilding
new_X = df2[['City','Latitude','Average Cost for two','Votes','Aggregate rating','Has Online delivery','Country','Currency','Rating color', 'Rating text']]

# %%
#standardizing the data

scalar=StandardScaler()
x_scalar=scalar.fit_transform(new_X)

# %% [markdown]
# # DecisionTreeClassifier Model

# %%
#import necessary librarys
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier #if regression then regressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Finding the Best Random State

# %%
#Finding the Best Random State
MaxAccu=0
MaxRS=0

for i in range (1,100):
    X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    dt=DecisionTreeClassifier()
    dt.fit(X_train_ns,y_train_ns)
    
    y_pred=dt.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    print ('Testing Accuracy' , accuracy , 'RandomState' ,i)
    print('\n')
    
    
    if accuracy>MaxAccu:
        MaxAccu=accuracy
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu , 'ON RANDOM STATE OF' , i)
# Out:
# Testing Accuracy 0.9895489548954896 RandomState 1
#
#
# MAXINING TESTING SCORE 0.9895489548954896 ON RANDOM STATE OF 1
# Testing Accuracy 0.988998899889989 RandomState 2
#
#
# Testing Accuracy 0.9928492849284929 RandomState 3
#
#
# MAXINING TESTING SCORE 0.9928492849284929 ON RANDOM STATE OF 3
# Testing Accuracy 0.9884488448844885 RandomState 4
#
#
# Testing Accuracy 0.9878987898789879 RandomState 5
#
#
# Testing Accuracy 0.9917491749174917 RandomState 6
#
#
# Testing Accuracy 0.988998899889989 RandomState 7
#
#
# Testing Accuracy 0.9878987898789879 RandomState 8
#
#
# Testing Accuracy 0.993949394939494 RandomState 9
#
#
# MAXINING TESTING SCORE 0.993949394939494 ON RANDOM STATE OF 9
# Testing Accuracy 0.9917491749174917 RandomState 10
#
#
# Testing Accuracy 0.9867986798679867 RandomState 11
#
#
# Testing Accuracy 0.9873487348734874 RandomState 12
#
#
# Testing Accuracy 0.9928492849284929 RandomState 13
#
#
# Testing Accuracy 0.988998899889989 RandomState 14
#
#
# ...

# %%
print('Best Accuracy is ' , MaxAccu , 'On Random State' , MaxRS)
# Out:
# Best Accuracy is  0.995049504950495 On Random State 76

# %% [markdown]
# ### Training the model

# %%
# train test split
X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=76)

# %%
#write one function and call as many time as you want
def metric_score (clf,X_train_ns,X_test,y_train_ns,y_test,train=True):
    if train:
        y_pred = clf.predict(X_train_ns)
        print ('====Training Score====')
        print (f"Accuracy score : {accuracy_score(y_train_ns,y_pred)*100:2f}%")
        
    elif train==False:
        pred = clf.predict(X_test)
        print ('====Testing Score====')
        print (f"Accuracy score : {accuracy_score(y_test,pred)*100:2f}%")
        
        print ('\n \n Classification report \n ' , classification_report(y_test,pred,digits=2))

# %%
# model initilization
clf_dt = DecisionTreeClassifier()
clf_dt.fit(X_train_ns,y_train_ns)
# Out:
# DecisionTreeClassifier()

# %%
# call the function
metric_score (clf_dt,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_dt,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 100.000000%
# ====Testing Score====
# Accuracy score : 99.339934%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1041
#            2       1.00      0.99      1.00       639
#            3       0.94      0.97      0.96       100
#            4       0.92      0.92      0.92        38
#
#     accuracy                           0.99      1818
#    macro avg       0.96      0.97      0.97      1818
# weighted avg       0.99      0.99      0.99      1818

# %% [markdown]
# ## Model Scores
# * Training Score = 100.000000%
# * Testing Score = 99.339934%

# %% [markdown]
# ## Hyperparameter For DecisionTree Classifier

# %%
# we are tuning 4 important hyperparameter rightnow we are passing the different value for both parameter
grid_param = {
                'criterion':['gini','entropy'],
                'max_depth':range(1,30),
                'min_samples_leaf':range(1,5),
                'min_samples_split':range(5,10),
                'max_leaf_nodes':range(1,10)
}

# %%
# here we are define some parameter and ask gridsearchcv which one is best
grid_search = GridSearchCV (estimator = clf_dt,param_grid=grid_param,cv=5,n_jobs=-1)

# %%
#pass dataset to train 
grid_search.fit(X_train_ns,y_train_ns)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 30),
#                          'max_leaf_nodes': range(1, 10),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(5, 10)})

# %%
# see best parameters
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 9, 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
#initiate what new parameter we got

clf_dt=DecisionTreeClassifier(criterion= 'gini', max_depth = 10, min_samples_leaf= 1, min_samples_split= 2)
clf_dt.fit(X_train_ns,y_train_ns)
# i tried different to get better results
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
# call the function
metric_score (clf_dt,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_dt,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 99.981661%
# ====Testing Score====
# Accuracy score : 99.394939%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1041
#            2       1.00      0.99      1.00       639
#            3       0.95      0.97      0.96       100
#            4       0.92      0.95      0.94        38
#
#     accuracy                           0.99      1818
#    macro avg       0.97      0.98      0.97      1818
# weighted avg       0.99      0.99      0.99      1818

# %% [markdown]
# ## Model Scores With Hyperparameter Tuning
# * Training Score = 99.981668%
# * Testing Score = 99.230346%

# %% [markdown]
# ## Cross Validation score for DecisionTree Classifier

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf_dt,x_scalar,y,cv=6)
# Out:
# array([0.43646865, 0.9290429 , 0.97194719, 0.99669967, 0.99834983,
#        0.94137077])

# %%
cross_val_score(clf_dt,x_scalar,y,cv=6).mean()
# Out:
# 0.877190567942013

# %% [markdown]
# ## Confusion Matrix DecisionTree Classifier

# %%
### if you want to check confusion matrix

y_pred=clf_dt.predict(X_test)
cfm=confusion_matrix(y_test,y_pred)
cfm
# Out:
# array([[1039,    2,    0,    0],
#        [   1,  635,    3,    0],
#        [   0,    0,   97,    3],
#        [   0,    0,    2,   36]], dtype=int64)

# %% [markdown]
# # RandomForest Classifier Model

# %%
#import necessary library

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier #RandomForestRegressor if regression problem
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Finding the Best Random State

# %%
#Finding the Best Random State
MaxAccu=0
MaxRS=0

for i in range (1,100):
    X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    rf = RandomForestClassifier()
    rf.fit(X_train_ns,y_train_ns)
    
    y_pred=rf.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    print ('Testing Accuracy' , accuracy , 'RandomState' ,i)
    print('\n')
    
    
    if accuracy>MaxAccu:
        MaxAccu=accuracy
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu , 'ON RANDOM STATE OF' , i)
# Out:
# Testing Accuracy 0.9873487348734874 RandomState 1
#
#
# MAXINING TESTING SCORE 0.9873487348734874 ON RANDOM STATE OF 1
# Testing Accuracy 0.9884488448844885 RandomState 2
#
#
# MAXINING TESTING SCORE 0.9884488448844885 ON RANDOM STATE OF 2
# Testing Accuracy 0.9873487348734874 RandomState 3
#
#
# Testing Accuracy 0.9856985698569857 RandomState 4
#
#
# Testing Accuracy 0.9807480748074807 RandomState 5
#
#
# Testing Accuracy 0.9862486248624862 RandomState 6
#
#
# Testing Accuracy 0.9862486248624862 RandomState 7
#
#
# Testing Accuracy 0.9856985698569857 RandomState 8
#
#
# Testing Accuracy 0.9922992299229924 RandomState 9
#
#
# MAXINING TESTING SCORE 0.9922992299229924 ON RANDOM STATE OF 9
# Testing Accuracy 0.9873487348734874 RandomState 10
#
#
# Testing Accuracy 0.9840484048404841 RandomState 11
#
#
# Testing Accuracy 0.9856985698569857 RandomState 12
#
#
# Testing Accuracy 0.9878987898789879 RandomState 13
#
#
# Testing Accuracy 0.9856985698569857 RandomState 14
#
#
# ...

# %%
print('Best Accuracy is ' , MaxAccu , 'On Random State' , MaxRS)
# Out:
# Best Accuracy is  0.9928492849284929 On Random State 76

# %% [markdown]
# ### Training the model

# %%
X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=76)

# %%
#write one function and call as many time as you want
def metric_score (clf,X_train_ns,X_test,y_train_ns,y_test,train=True):
    if train:
        y_pred = clf.predict(X_train_ns)
        print ('====Training Score====')
        print (f"Accuracy score : {accuracy_score(y_train_ns,y_pred)*100:2f}%")
        
    elif train==False:
        pred = clf.predict(X_test)
        print ('====Testing Score====')
        print (f"Accuracy score : {accuracy_score(y_test,pred)*100:2f}%")
        
        print ('\n \n Classification report \n ' , classification_report(y_test,pred,digits=2))

# %%
# model initilization
clf_rf = RandomForestClassifier()
clf_rf.fit(X_train_ns,y_train_ns)
# Out:
# RandomForestClassifier()

# %%
# call the function
metric_score (clf_rf,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_rf,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 100.000000%
# ====Testing Score====
# Accuracy score : 99.064906%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1062
#            2       1.00      0.99      0.99       636
#            3       0.91      0.95      0.93        93
#            4       0.85      0.81      0.83        27
#
#     accuracy                           0.99      1818
#    macro avg       0.94      0.94      0.94      1818
# weighted avg       0.99      0.99      0.99      1818

# %% [markdown]
# ## Model Scores
# * Training Score = 100.000000%
# * Testing Score = 99.064906%

# %% [markdown]
# ## Hyperparameter For RandomForestClassifier

# %%
# we are tuning 4 important hyperparameter rightnow we are passing the different value for both parameter
params_grid = {'n_estimators' : range(1,5),
               'criterion' : ['entropy' , 'gini'],
               'max_depth' : range(1,30),
               'min_samples_split' :range(5,10),
               'min_samples_leaf':range(1,10)}

# %%
# here we are define some parameter and ask gridsearchcv which one is best
grd = GridSearchCV(clf_rf,param_grid = params_grid)

# %%
#pass dataset to train 
grd.fit(X_train_ns,y_train_ns)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': range(1, 30),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(5, 10),
#                          'n_estimators': range(1, 5)})

# %%
print ('Best parameters : ' , grd.best_params_) #printing best parameters
# Out:
# Best parameters :  {'criterion': 'entropy', 'max_depth': 22, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 4}

# %%
#initiate what new parameter we got
rf=RandomForestClassifier(criterion= 'entropy', max_depth = 11, min_samples_leaf= 4, min_samples_split= 8,n_estimators= 3)
rf.fit(X_train_ns,y_train_ns)

#i tried different combination and i find this is best parameter so using this instead of gridsearch parameters
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=11, min_samples_leaf=4,
#                        min_samples_split=8, n_estimators=3)

# %%
# call the function
metric_score (rf,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (rf,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 97.267559%
# ====Testing Score====
# Accuracy score : 96.864686%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1062
#            2       0.97      0.97      0.97       636
#            3       0.75      0.78      0.77        93
#            4       0.68      0.48      0.57        27
#
#     accuracy                           0.97      1818
#    macro avg       0.85      0.81      0.82      1818
# weighted avg       0.97      0.97      0.97      1818

# %% [markdown]
# ## Model Scores With Hyperparameter Tuning
# * Training Score =  97.267559%
# * Testing Score = 96.864686%

# %% [markdown]
# ## Cross Validation score for RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(rf,x_scalar,y,cv=6)
# Out:
# array([0.56848185, 0.92656766, 0.97194719, 0.98184818, 0.98762376,
#        0.93971924])

# %%
cross_val_score(rf,x_scalar,y,cv=6).mean()
# Out:
# 0.9525518509737019

# %% [markdown]
# ## Confusion Matrix RandomForestClassifier

# %%
### if you want to check confusion matrix

y_pred=rf.predict(X_test)
cfm=confusion_matrix(y_test,y_pred)
cfm
# Out:
# array([[1057,    5,    0,    0],
#        [   5,  618,   11,    2],
#        [   0,   16,   73,    4],
#        [   0,    1,   13,   13]], dtype=int64)

# %% [markdown]
# # KNeighborsClassifier Model

# %%
#import necessary library

import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Finding the Best Random State

# %%
#Finding the Best Random State
MaxAccu=0
MaxRS=0

for i in range (1,100):
    X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    knn = KNeighborsClassifier()
    knn.fit(X_train_ns,y_train_ns)
    
    y_pred=rf.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    print ('Testing Accuracy' , accuracy , 'RandomState' ,i)
    print('\n')
    
    
    if accuracy>MaxAccu:
        MaxAccu=accuracy
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu , 'ON RANDOM STATE OF' , i)
# Out:
# Testing Accuracy 0.9735973597359736 RandomState 1
#
#
# MAXINING TESTING SCORE 0.9735973597359736 ON RANDOM STATE OF 1
# Testing Accuracy 0.9757975797579758 RandomState 2
#
#
# MAXINING TESTING SCORE 0.9757975797579758 ON RANDOM STATE OF 2
# Testing Accuracy 0.9697469746974697 RandomState 3
#
#
# Testing Accuracy 0.9680968096809681 RandomState 4
#
#
# Testing Accuracy 0.9702970297029703 RandomState 5
#
#
# Testing Accuracy 0.9724972497249725 RandomState 6
#
#
# Testing Accuracy 0.9741474147414741 RandomState 7
#
#
# Testing Accuracy 0.9691969196919692 RandomState 8
#
#
# Testing Accuracy 0.971947194719472 RandomState 9
#
#
# Testing Accuracy 0.9752475247524752 RandomState 10
#
#
# Testing Accuracy 0.9697469746974697 RandomState 11
#
#
# Testing Accuracy 0.9686468646864687 RandomState 12
#
#
# Testing Accuracy 0.9702970297029703 RandomState 13
#
#
# Testing Accuracy 0.9702970297029703 RandomState 14
#
#
# Testing Accuracy 0.9642464246424642 RandomState 15
#
#
# ...

# %%
print('Best Accuracy is ' , MaxAccu , 'On Random State' , MaxRS)
# Out:
# Best Accuracy is  0.9785478547854786 On Random State 65

# %% [markdown]
# ### Training the model

# %%
X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=65)

# %%
#write one function and call as many time as you want
def metric_score (clf,X_train_ns,X_test,y_train_ns,y_test,train=True):
    if train:
        y_pred = clf.predict(X_train_ns)
        print ('====Training Score====')
        print (f"Accuracy score : {accuracy_score(y_train_ns,y_pred)*100:2f}%")
        
    elif train==False:
        pred = clf.predict(X_test)
        print ('====Testing Score====')
        print (f"Accuracy score : {accuracy_score(y_test,pred)*100:2f}%")
        
        print ('\n \n Classification report \n ' , classification_report(y_test,pred,digits=2))

# %%
# model initilization
clf_knn = KNeighborsClassifier()
clf_knn.fit(X_train_ns,y_train_ns)
# Out:
# KNeighborsClassifier()

# %%
# call the function
metric_score (clf_knn,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_knn,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 97.029158%
# ====Testing Score====
# Accuracy score : 95.654565%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98      1047
#            2       0.94      0.97      0.95       652
#            3       0.76      0.74      0.75        86
#            4       0.90      0.55      0.68        33
#
#     accuracy                           0.96      1818
#    macro avg       0.90      0.81      0.84      1818
# weighted avg       0.96      0.96      0.96      1818

# %% [markdown]
# ## Model Scores
# * Training Score = 97.029158%
# * Testing Score = 95.654565%

# %% [markdown]
# ## Hyperparameter For KNeighborsClassifier

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'algorithm':['kd_tree','brute'],
            'leaf_size':[3,5,6,7,8],
            'n_neighbors':[3,5,7,9,11,13]}

# %%
# now call grid search and say that we are going to use knn model

gridsearch=GridSearchCV(estimator=clf_knn , param_grid=param_grid)

# %%
#give the data to object
gridsearch.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['kd_tree', 'brute'],
#                          'leaf_size': [3, 5, 6, 7, 8],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13]})

# %%
#see the best paramater

gridsearch.best_params_
# Out:
# {'algorithm': 'brute', 'leaf_size': 3, 'n_neighbors': 3}

# %%
# we will use the best parameter in our knn algorithm and check if accuracy is increase or not
clf_knn=KNeighborsClassifier(algorithm = 'kd_tree', leaf_size = 3, n_neighbors = 5)

clf_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=3)

# %%
# call the function
metric_score (clf_knn,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_knn,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 96.827434%
# ====Testing Score====
# Accuracy score : 96.809681%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       0.99      0.98      0.99      1047
#            2       0.95      0.98      0.97       652
#            3       0.81      0.84      0.82        86
#            4       0.90      0.55      0.68        33
#
#     accuracy                           0.97      1818
#    macro avg       0.91      0.84      0.86      1818
# weighted avg       0.97      0.97      0.97      1818

# %% [markdown]
# ## Model Scores With Hyperparameter Tuning
# * Training Score = 96.773602%
# * Testing Score = 95.272128%

# %% [markdown]
# ## Cross Validation score for KNeighborsClassifier

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf_knn,x_scalar,y,cv=6)
# Out:
# array([0.46864686, 0.90016502, 0.9529703 , 0.97524752, 0.97772277,
#        0.93724195])

# %%
cross_val_score(rf,x_scalar,y,cv=6).mean()
# Out:
# 0.9284858089442305

# %% [markdown]
# ## Confusion Matric for KNN

# %%
### if you want to check confusion matrix

y_pred=clf_knn.predict(X_test)
cfm=confusion_matrix(y_test,y_pred)
cfm
# Out:
# array([[1030,   17,    0,    0],
#        [   8,  640,    3,    1],
#        [   0,   13,   72,    1],
#        [   0,    1,   14,   18]], dtype=int64)

# %% [markdown]
# # Support Vector Machine Model

# %%
# Import necessary model #
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')
# svc model 
# for classification
from sklearn.svm import SVC

# %%
#Finding the Best Random State
MaxAccu=0
MaxRS=0

for i in range (1,100):
    X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=i)
    svc=SVC()
    svc.fit(X_train_ns,y_train_ns)
    
    y_pred=svc.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    print ('Testing Accuracy' , accuracy , 'RandomState' ,i)
    print('\n')
    
    
    if accuracy>MaxAccu:
        MaxAccu=accuracy
        MaxRS=i
        print('MAXINING TESTING SCORE' , MaxAccu , 'ON RANDOM STATE OF' , i)
# Out:
# Testing Accuracy 0.9664466446644664 RandomState 1
#
#
# MAXINING TESTING SCORE 0.9664466446644664 ON RANDOM STATE OF 1
# Testing Accuracy 0.9675467546754676 RandomState 2
#
#
# MAXINING TESTING SCORE 0.9675467546754676 ON RANDOM STATE OF 2
# Testing Accuracy 0.9653465346534653 RandomState 3
#
#
# Testing Accuracy 0.9647964796479648 RandomState 4
#
#
# Testing Accuracy 0.9680968096809681 RandomState 5
#
#
# MAXINING TESTING SCORE 0.9680968096809681 ON RANDOM STATE OF 5
# Testing Accuracy 0.9724972497249725 RandomState 6
#
#
# MAXINING TESTING SCORE 0.9724972497249725 ON RANDOM STATE OF 6
# Testing Accuracy 0.966996699669967 RandomState 7
#
#
# Testing Accuracy 0.9620462046204621 RandomState 8
#
#
# Testing Accuracy 0.9691969196919692 RandomState 9
#
#
# Testing Accuracy 0.9680968096809681 RandomState 10
#
#
# Testing Accuracy 0.9581958195819582 RandomState 11
#
#
# Testing Accuracy 0.9581958195819582 RandomState 12
#
#
# Testing Accuracy 0.9691969196919692 RandomState 13
#
#
# ...

# %%
print('Best Accuracy is ' , MaxAccu , 'On Random State' , MaxRS)
# Out:
# Best Accuracy is  0.9752475247524752 On Random State 59

# %%
# train test split
X_train_ns,X_test,y_train_ns,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=59)

# %%
#write one function and call as many time as you want
def metric_score (clf,X_train_ns,X_test,y_train_ns,y_test,train=True):
    if train:
        y_pred = clf.predict(X_train_ns)
        print ('====Training Score====')
        print (f"Accuracy score : {accuracy_score(y_train_ns,y_pred)*100:2f}%")
        
    elif train==False:
        pred = clf.predict(X_test)
        print ('====Testing Score====')
        print (f"Accuracy score : {accuracy_score(y_test,pred)*100:2f}%")
        
        print ('\n \n Classification report \n ' , classification_report(y_test,pred,digits=2))

# %%
clf_svc=SVC()
clf_svc.fit(X_train_ns,y_train_ns)
# Out:
# SVC()

# %%
# call the function
metric_score (clf_svc,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (clf_svc,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 97.469283%
# ====Testing Score====
# Accuracy score : 97.524752%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99      1062
#            2       0.96      0.99      0.97       636
#            3       0.89      0.87      0.88        93
#            4       0.81      0.81      0.81        27
#
#     accuracy                           0.98      1818
#    macro avg       0.92      0.91      0.91      1818
# weighted avg       0.98      0.98      0.98      1818

# %% [markdown]
# ## Model Scores
#     Training Score = 97.469283%
#     Testing Score = 97.524752%

# %% [markdown]
# ## Hyperparameter Tuning for SVC

# %%
## HYPERPARAMETER TUNING ##
# here we tune only 2 parameter c and gamma
# where c = how much error we allow model to do 
# gamma = it decide how much curvature we want in a decision boundary 

from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[1,5,10,20],
           'gamma':[0.001,0.01,0.02,0.002]}

# %%
# here we are define some parameter and ask gridsearchcv which one is best
gridsearch=GridSearchCV(svc,param_grid)

# %%
#pass dataset to train 
gridsearch.fit(X_train_ns,y_train_ns)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'gamma': [0.001, 0.01, 0.02, 0.002]})

# %%
#best parameters
gridsearch.best_params_
# Out:
# {'C': 20, 'gamma': 0.01}

# %%
# update our model and train again for new score 
svc=SVC(C=20,gamma=0.01)
svc.fit(X_train_ns,y_train_ns)
# Out:
# SVC(C=20, gamma=0.01)

# %%
# call the function
metric_score (svc,X_train_ns,X_test,y_train_ns,y_test,train = True)
metric_score (svc,X_train_ns,X_test,y_train_ns,y_test,train=False)
# Out:
# ====Training Score====
# Accuracy score : 98.092793%
# ====Testing Score====
# Accuracy score : 98.129813%
#
#
#  Classification report
#                 precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1062
#            2       0.99      0.98      0.98       636
#            3       0.87      0.88      0.88        93
#            4       0.73      0.81      0.77        27
#
#     accuracy                           0.98      1818
#    macro avg       0.90      0.92      0.91      1818
# weighted avg       0.98      0.98      0.98      1818

# %% [markdown]
# ## Model Scores With Hyperparameter Tuning
#     Training Score = 98.092793%
#     Testing Score = 98.129813%

# %% [markdown]
# ## Cross-Validation Score For SVC

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svc,x_scalar,y,cv=6)
# Out:
# array([0.91419142, 0.96122112, 0.97937294, 0.9950495 , 0.99587459,
#        0.95788604])

# %%
cross_val_score(svc,x_scalar,y,cv=6).mean()
# Out:
# 0.9672659359247238

# %% [markdown]
# ## Confusion Matrix for SVC

# %%
### if you want to check confusion matrix

y_pred=svc.predict(X_test)
cfm=confusion_matrix(y_test,y_pred)
cfm
# Out:
# array([[1059,    3,    0,    0],
#        [   8,  621,    7,    0],
#        [   0,    3,   82,    8],
#        [   0,    0,    5,   22]], dtype=int64)

# %% [markdown]
# # All model score after hyperparameter tuning
#
# ** Decision Tree Classifier Model
#
#     Training Score = 100.000000%
#     Testing Score = 99.339934%
#     Cross Validation score=87.7190567942013%
#
#
# ** Random Forest Classifier Model
#
#     Training Score = 100.000000%
#     Testing Score = 99.064906%
#     Cross Validation score = 95.25518509737019%
#
#
# ** KNeighbors Classifier Model
#
#     Training Score = 97.029158%
#     Testing Score = 95.654565%
#     Cross Validation score=92.84858089442305%
#
#
# ** Support Vector Machine Model
#
#     Training Score = 97.469283%
#     Testing Score = 97.524752%
#     Cross Validation score=96.72659359247238%

# %% [markdown]
# ## So from the above all 4 models scores, we select the SVC model as the best model suited for this particular problem because its training score = 97.469283% and testing score =97.524752%  is almost the same and when it comes to the Cross-validation score SVC score is greater as compared to another model which is Cross Validation score=96.72659359247%.

# %% [markdown]
# ## Saving the best Model

# %%
# now we save this is modeland transfer to other by using pickel

#first save this model to the local file system 
import pickle
pickle.dump(svc , open ('reg_model' , 'wb'))
